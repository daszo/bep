# %%
print("start")
# Out:
# start

# %%
import os
DATASET_PATH = "../maildir" 

for root, dirs, files in os.walk(DATASET_PATH):
    print(root)
# Out:
# ../maildir
# ../maildir/blair-l
# ../maildir/blair-l/personnel___promotions
# ../maildir/blair-l/meetings___nng_customer_mtg
# ../maildir/blair-l/nng___sla_settlement
# ../maildir/blair-l/tw___negotiated_rates_issues
# ../maildir/blair-l/customer___uses
# ../maildir/blair-l/training___business_objects
# ../maildir/blair-l/tw___imbalances___netting_trading
# ../maildir/blair-l/customer___oneok
# ../maildir/blair-l/customer___virginia_power_dominion
# ../maildir/blair-l/vacations_2001
# ../maildir/blair-l/itinerary_off_duty
# ../maildir/blair-l/presentations
# ../maildir/blair-l/move
# ../maildir/blair-l/demarc_allocation
# ../maildir/blair-l/daily_updates___12_1_01
# ../maildir/blair-l/tw___invoicing
# ../maildir/blair-l/expense_reports
# ../maildir/blair-l/weekly_reports___2001
# ../maildir/blair-l/merger_with_dynegy
# ../maildir/blair-l/dra_info
# ../maildir/blair-l/christmas_cards_list
# ../maildir/blair-l/ipayit_information
# ../maildir/blair-l/inbox
# ../maildir/blair-l/tropical_storm_allison
# ../maildir/blair-l/nng___sba
# ../maildir/blair-l/ibuyit_information
# ../maildir/blair-l/tw___marketing
# ../maildir/blair-l/tw___transactional_requirements
# ../maildir/blair-l/meetings___general
# ../maildir/blair-l/outbox
# ../maildir/blair-l/training___2001
# ../maildir/blair-l/budget___2002
# ../maildir/blair-l/meetings
# ../maildir/blair-l/tw___procedures
# ../maildir/blair-l/personal
# ../maildir/blair-l/customer___alliant
# ../maildir/blair-l/donna
# ../maildir/blair-l/personnel___advance_hire_assoc
# ../maildir/blair-l/acctg___customer_issues_on_billing
# ../maildir/blair-l/personnel___paa
# ../maildir/blair-l/shipper_list
# ../maildir/blair-l/tw___nwpl_budget
# ../maildir/blair-l/customer___ena
# ../maildir/blair-l/tw___citizens_agreement
# ../maildir/blair-l/nbpl_information
# ../maildir/blair-l/contacts
# ../maildir/blair-l/storage___alloc_process
# ../maildir/blair-l/personnel___ava_s_duties
# ../maildir/blair-l/sent_items
# ../maildir/blair-l/meetings___tw_customer
# ../maildir/blair-l/tw___socal_window_procedure
# ../maildir/blair-l/reports___scheduled_quantity_report
# ../maildir/blair-l/carlton_resolution
# ../maildir/blair-l/print
# ../maildir/blair-l/storage___third_party_storage_info
# ../maildir/blair-l/personnel___working_from_home
# ../maildir/blair-l/acctg___2001_new_accctg_sys
# ../maildir/blair-l/acctg___measurement_issues
# ../maildir/blair-l/personnel___shift_differential
# ../maildir/blair-l/deleted_items
# ../maildir/blair-l/deleted_items/_sent_mail
# ../maildir/blair-l/personnel___prc_2001_mid_yr
# ../maildir/blair-l/budget___2001
# ../maildir/blair-l/outlook_instructions
# ../maildir/blair-l/personnel___prc_2001_year_end
# ../maildir/blair-l/_sent_mail
# ../maildir/blair-l/customer___reliant_retail_energy_minneapolis
# ../maildir/blair-l/customer___midam
# ../maildir/blair-l/acctg___invoicing_info
# ../maildir/badeer-r
# ../maildir/badeer-r/memo_s
# ../maildir/badeer-r/all_documents
# ../maildir/badeer-r/notes_inbox
# ../maildir/badeer-r/move
# ../maildir/badeer-r/inbox
# ../maildir/badeer-r/dj_articles
# ../maildir/badeer-r/discussion_threads
# ../maildir/badeer-r/contacts
# ../maildir/badeer-r/sent_items
# ../maildir/badeer-r/var
# ../maildir/badeer-r/deleted_items
# ../maildir/badeer-r/cal_articles
# ../maildir/badeer-r/capx
# ../maildir/badeer-r/press_releases
# ../maildir/badeer-r/california
# ../maildir/badeer-r/_sent_mail
# ../maildir/ring-r
# ../maildir/ring-r/eesimarketstexas
# ../maildir/ring-r/eesidealsgsaregion1
# ../maildir/ring-r/inbox
# ../maildir/ring-r/inbox/eesiresponsesrfp
# ../maildir/ring-r/eesiisonewengland
# ../maildir/ring-r/outbox
# ../maildir/ring-r/eesi_deleted_documents
# ../maildir/ring-r/personalfolder
# ../maildir/ring-r/eesirenewableenergy
# ../maildir/ring-r/eesiphysicalpowerdelivery
# ../maildir/ring-r/eesiisonewyork
# ../maildir/ring-r/sent_items
# ../maildir/ring-r/deleted_items
# ../maildir/ring-r/eesiisopjm
# ../maildir/cuilla-m
# ../maildir/cuilla-m/all_documents
# ../maildir/cuilla-m/notes_inbox
# ../maildir/cuilla-m/inbox
# ../maildir/cuilla-m/10_fantasy
# ../maildir/cuilla-m/10_fantasy/requests
# ../maildir/cuilla-m/discussion_threads
# ../maildir/cuilla-m/personal
# ../maildir/cuilla-m/sent
# ../maildir/cuilla-m/bernhardt
# ../maildir/cuilla-m/sent_items
# ../maildir/cuilla-m/12_fantasy
# ../maildir/cuilla-m/deleted_items
# ../maildir/cuilla-m/_sent_mail
# ../maildir/harris-s
# ../maildir/harris-s/inbox
# ../maildir/harris-s/deleted_items
# ../maildir/mckay-b
# ../maildir/mckay-b/all_documents
# ../maildir/mckay-b/notes_inbox
# ../maildir/mckay-b/inbox
# ../maildir/mckay-b/discussion_threads
# ../maildir/mckay-b/sent
# ../maildir/mckay-b/sent_items
# ../maildir/mckay-b/deleted_items
# ../maildir/mckay-b/_sent_mail
# ../maildir/corman-s
# ../maildir/corman-s/ingaastudy
# ../maildir/corman-s/osha
# ../maildir/corman-s/all_documents
# ../maildir/corman-s/calendar
# ../maildir/corman-s/inbox
# ../maildir/corman-s/inbox/bankruptcy
# ../maildir/corman-s/inbox/oneok
# ../maildir/corman-s/inbox/budget
# ../maildir/corman-s/inbox/vacation_schedules
# ../maildir/corman-s/inbox/archives___post_revised_order
# ../maildir/corman-s/inbox/tw_neg_rates
# ../maildir/corman-s/inbox/measurement
# ../maildir/corman-s/inbox/naesb
# ../maildir/corman-s/inbox/twdatarequests
# ../maildir/corman-s/inbox/archives
# ../maildir/corman-s/inbox/archives/old_messages
# ../maildir/corman-s/inbox/kidsave
# ../maildir/corman-s/discussion_threads
# ../maildir/corman-s/contacts
# ../maildir/corman-s/sent_items
# ../maildir/corman-s/marketingaffiliate
# ../maildir/corman-s/deleted_items
# ../maildir/corman-s/communications
# ../maildir/scholtes-d
# ../maildir/scholtes-d/to_do
# ../maildir/scholtes-d/lt_contracts
# ../maildir/scholtes-d/calendar
# ../maildir/scholtes-d/inbox
# ../maildir/scholtes-d/mid_columbia
# ../maildir/scholtes-d/outbox
# ../maildir/scholtes-d/outbox/personal
# ../maildir/scholtes-d/outbox/personal/untitled
# ../maildir/scholtes-d/west_bank
# ../maildir/scholtes-d/transmission
# ../maildir/scholtes-d/ferc
# ../maildir/scholtes-d/sent_items
# ../maildir/scholtes-d/travel
# ../maildir/scholtes-d/belden
# ../maildir/scholtes-d/stf
# ../maildir/scholtes-d/stf/current_issues
# ../maildir/scholtes-d/stf/e_tag
# ../maildir/scholtes-d/credit
# ../maildir/scholtes-d/credit/risk
# ../maildir/scholtes-d/diana_scholtes
# ../maildir/scholtes-d/diana_scholtes/saved_sent
# ../maildir/scholtes-d/scheduling
# ../maildir/scholtes-d/fundementals
# ../maildir/scholtes-d/it
# ../maildir/scholtes-d/tasks
# ../maildir/scholtes-d/policy
# ../maildir/scholtes-d/settlements
# ../maildir/whalley-g
# ../maildir/whalley-g/all_documents
# ../maildir/whalley-g/to_do
# ../maildir/whalley-g/notes_inbox
# ../maildir/whalley-g/calendar
# ../maildir/whalley-g/economics
# ../maildir/whalley-g/controls
# ../maildir/whalley-g/inbox
# ../maildir/whalley-g/discussion_threads
# ../maildir/whalley-g/personal
# ../maildir/whalley-g/sent
# ../maildir/whalley-g/merchant_investments
# ../maildir/whalley-g/india
# ../maildir/whalley-g/test
# ../maildir/whalley-g/test/calendar
# ../maildir/whalley-g/test/contacts
# ../maildir/whalley-g/test/tasks
# ../maildir/whalley-g/contacts
# ../maildir/whalley-g/connect_deletes
# ../maildir/whalley-g/sent_items
# ../maildir/whalley-g/markets
# ../maildir/whalley-g/deleted_items
# ../maildir/whalley-g/mariner
# ../maildir/whalley-g/tasks
# ../maildir/whalley-g/_sent_mail
# ../maildir/cash-m
# ../maildir/cash-m/all_documents
# ../maildir/cash-m/notes_inbox
# ../maildir/cash-m/bankruptcy
# ../maildir/cash-m/outlook_migration
# ../maildir/cash-m/daishowa
# ../maildir/cash-m/star_wars
# ../maildir/cash-m/inbox
# ../maildir/cash-m/inbox/dlr
# ../maildir/cash-m/ethics_ljm_notre_dame
# ../maildir/cash-m/play_group
# ../maildir/cash-m/garden_state_paper
# ../maildir/cash-m/phone_lists
# ../maildir/cash-m/project_50
# ../maildir/cash-m/ei_execs
# ../maildir/cash-m/msa_revisions
# ../maildir/cash-m/personal
# ../maildir/cash-m/resumes_for_recruiting
# ../maildir/cash-m/sent
# ../maildir/cash-m/ibuyit
# ../maildir/cash-m/data_protection
# ../maildir/cash-m/contacts
# ../maildir/cash-m/organizational_announcements
# ../maildir/cash-m/connect_deletes
# ../maildir/cash-m/sent_items
# ../maildir/cash-m/n_form
# ../maildir/cash-m/meeting_invites_confirms
# ../maildir/cash-m/meeting_invites_confirms/labor_resumes
# ../maildir/cash-m/hr_risk_management
# ../maildir/cash-m/deleted_items
# ../maildir/cash-m/prc
# ../maildir/cash-m/general_research
# ../maildir/benson-r
# ../maildir/benson-r/all_documents
# ../maildir/benson-r/notes_inbox
# ../maildir/benson-r/calendar
# ../maildir/benson-r/inbox
# ../maildir/benson-r/inbox/large_messages
# ../maildir/benson-r/discussion_threads
# ../maildir/benson-r/sent
# ../maildir/benson-r/sent_items
# ../maildir/benson-r/deleted_items
# ../maildir/benson-r/_sent_mail
# ../maildir/hain-m
# ../maildir/hain-m/all_documents
# ../maildir/hain-m/notes_inbox
# ../maildir/hain-m/discussion_threads
# ../maildir/hain-m/my_personal
# ../maildir/hain-m/_sent_mail
# ../maildir/guzman-m
# ../maildir/guzman-m/all_documents
# ../maildir/guzman-m/notes_inbox
# ../maildir/guzman-m/discussion_threads
# ../maildir/guzman-m/_sent_mail
# ../maildir/may-l
# ../maildir/may-l/all_documents
# ../maildir/may-l/notes_inbox
# ../maildir/may-l/calendar
# ../maildir/may-l/inbox
# ../maildir/may-l/discussion_threads
# ../maildir/may-l/sent
# ../maildir/may-l/sent_items
# ../maildir/may-l/deleted_items
# ../maildir/may-l/_sent_mail
# ../maildir/keiser-k
# ../maildir/keiser-k/to_do
# ../maildir/keiser-k/calendar
# ../maildir/keiser-k/inbox
# ../maildir/keiser-k/sent_items
# ../maildir/keiser-k/deleted_items
# ../maildir/lay-k
# ../maildir/lay-k/all_documents
# ../maildir/lay-k/notes_inbox
# ../maildir/lay-k/calendar
# ../maildir/lay-k/business
# ../maildir/lay-k/inbox
# ../maildir/lay-k/discussion_threads
# ../maildir/lay-k/enron
# ../maildir/lay-k/sent
# ../maildir/lay-k/compaq
# ../maildir/lay-k/sec_panel
# ../maildir/lay-k/sent_items
# ../maildir/lay-k/_sent
# ../maildir/lay-k/elizabeth
# ../maildir/lay-k/family
# ../maildir/lay-k/deleted_items
# ../maildir/neal-s
# ../maildir/neal-s/ngpl
# ../maildir/neal-s/all_documents
# ../maildir/neal-s/notes_inbox
# ../maildir/neal-s/calendar
# ../maildir/neal-s/storage
# ../maildir/neal-s/transport
# ../maildir/neal-s/inbox
# ../maildir/neal-s/lrc_bridgeline
# ../maildir/neal-s/discussion_threads
# ../maildir/neal-s/eol
# ../maildir/neal-s/regulatory
# ../maildir/neal-s/sent
# ../maildir/neal-s/prc_ass_mid00
# ../maildir/neal-s/sent_items
# ../maildir/neal-s/bug
# ../maildir/neal-s/vng
# ../maildir/neal-s/credit
# ../maildir/neal-s/miscellaneous
# ../maildir/neal-s/deleted_items
# ../maildir/neal-s/florida
# ../maildir/neal-s/_sent_mail
# ../maildir/heard-m
# ../maildir/heard-m/all_documents
# ../maildir/heard-m/inbox
# ../maildir/heard-m/inbox/master_netting
# ../maildir/heard-m/sent
# ../maildir/heard-m/brokerage_agreements
# ../maildir/heard-m/sent_items
# ../maildir/heard-m/deleted_items
# ../maildir/presto-k
# ../maildir/presto-k/all_documents
# ../maildir/presto-k/calendar
# ../maildir/presto-k/inbox
# ../maildir/presto-k/discussion_threads
# ../maildir/presto-k/sent
# ../maildir/presto-k/sent_items
# ../maildir/presto-k/presto_files
# ../maildir/presto-k/presto_working_files
# ../maildir/presto-k/presto_working_files/oneok
# ../maildir/presto-k/presto_working_files/personnel_issues
# ../maildir/presto-k/presto_working_files/assoc_analyst
# ../maildir/presto-k/presto_working_files/resumes
# ../maildir/presto-k/presto_working_files/ees_2_ways
# ../maildir/presto-k/presto_working_files/personal_files
# ../maildir/presto-k/deleted_items
# ../maildir/presto-k/junk_e_mail
# ../maildir/quigley-d
# ../maildir/quigley-d/fin_desk
# ../maildir/quigley-d/_exchange_pos
# ../maildir/quigley-d/calendar
# ../maildir/quigley-d/bmr
# ../maildir/quigley-d/ina
# ../maildir/quigley-d/inbox
# ../maildir/quigley-d/_exchange
# ../maildir/quigley-d/myfriends
# ../maildir/quigley-d/carr
# ../maildir/quigley-d/sent_items
# ../maildir/quigley-d/mid_market
# ../maildir/quigley-d/_exchange_info
# ../maildir/quigley-d/deleted_items
# ../maildir/quigley-d/private_folders
# ../maildir/quigley-d/private_folders/ffl
# ../maildir/quigley-d/private_folders/kq___dq
# ../maildir/quigley-d/prc
# ../maildir/causholli-m
# ../maildir/causholli-m/calendar
# ../maildir/causholli-m/inbox
# ../maildir/causholli-m/sent_items
# ../maildir/causholli-m/deleted_items
# ../maildir/martin-t
# ../maildir/martin-t/all_documents
# ../maildir/martin-t/calendar
# ../maildir/martin-t/inbox
# ../maildir/martin-t/discussion_threads
# ../maildir/martin-t/sent
# ../maildir/martin-t/contacts
# ../maildir/martin-t/sent_items
# ../maildir/martin-t/tom_s_docs
# ../maildir/martin-t/deleted_items
# ../maildir/martin-t/_sent_mail
# ../maildir/williams-w3
# ../maildir/williams-w3/rt_strat
# ../maildir/williams-w3/canada
# ../maildir/williams-w3/gwolfe
# ../maildir/williams-w3/tie_meter_multipliers
# ../maildir/williams-w3/calendar
# ../maildir/williams-w3/inbox
# ../maildir/williams-w3/operations_committee_isas
# ../maildir/williams-w3/rt_cuts
# ../maildir/williams-w3/symesees
# ../maildir/williams-w3/personal
# ../maildir/williams-w3/forney
# ../maildir/williams-w3/bill
# ../maildir/williams-w3/human_resources
# ../maildir/williams-w3/contacts
# ../maildir/williams-w3/hr
# ../maildir/williams-w3/preschedule
# ../maildir/williams-w3/sent_items
# ../maildir/williams-w3/california_messages
# ../maildir/williams-w3/schedule_crawler
# ../maildir/williams-w3/enron_messages
# ../maildir/williams-w3/el_paso
# ../maildir/williams-w3/settlements
# ../maildir/williams-w3/bill_williams_iii
# ../maildir/williams-w3/timbelden
# ../maildir/dickson-s
# ../maildir/dickson-s/all_documents
# ../maildir/dickson-s/sent
# ../maildir/dickson-s/pictures
# ../maildir/lenhart-m
# ../maildir/lenhart-m/all_documents
# ../maildir/lenhart-m/notes_inbox
# ../maildir/lenhart-m/inbox
# ../maildir/lenhart-m/discussion_threads
# ../maildir/lenhart-m/sent
# ../maildir/lenhart-m/sent_items
# ../maildir/lenhart-m/deleted_items
# ../maildir/rodrique-r
# ../maildir/rodrique-r/canada
# ../maildir/rodrique-r/all_documents
# ../maildir/rodrique-r/discussion_threads
# ../maildir/rodrique-r/israel_estrada
# ../maildir/rodrique-r/sent
# ../maildir/rodrique-r/dublin
# ../maildir/rodrique-r/file
# ../maildir/rodrique-r/_sent_mail
# ../maildir/panus-s
# ../maildir/panus-s/all_documents
# ../maildir/panus-s/inbox
# ../maildir/panus-s/contacts
# ../maildir/panus-s/sent_items
# ../maildir/panus-s/deleted_items
# ../maildir/taylor-m
# ../maildir/taylor-m/uk_trading
# ../maildir/taylor-m/yoder
# ../maildir/taylor-m/all_documents
# ../maildir/taylor-m/credit_watch_list
# ../maildir/taylor-m/to_do
# ../maildir/taylor-m/notes_inbox
# ../maildir/taylor-m/cftc
# ../maildir/taylor-m/inbox
# ../maildir/taylor-m/inbox/trades
# ../maildir/taylor-m/inbox/esource
# ../maildir/taylor-m/inbox/coe2
# ../maildir/taylor-m/inbox/compression
# ../maildir/taylor-m/inbox/mid_marketing
# ../maildir/taylor-m/inbox/so2
# ../maildir/taylor-m/inbox/cranes
# ../maildir/taylor-m/inbox/tnrcc
# ../maildir/taylor-m/inbox/noxtech
# ../maildir/taylor-m/inbox/enron_south
# ../maildir/taylor-m/inbox/options
# ../maildir/taylor-m/inbox/atlanta
# ../maildir/taylor-m/inbox/trevor
# ../maildir/taylor-m/inbox/parking
# ../maildir/taylor-m/inbox/emissions_e_mail
# ../maildir/taylor-m/inbox/methanol_plant
# ../maildir/taylor-m/inbox/marketing
# ../maildir/taylor-m/inbox/ev
# ../maildir/taylor-m/inbox/recruiting
# ../maildir/taylor-m/inbox/lisa_j
# ../maildir/taylor-m/inbox/social
# ../maildir/taylor-m/inbox/forbes
# ../maildir/taylor-m/inbox/analyst_prog
# ../maildir/taylor-m/inbox/nox_model
# ../maildir/taylor-m/inbox/nox_model/websites
# ../maildir/taylor-m/inbox/passwords
# ../maildir/taylor-m/inbox/john_mas
# ../maildir/taylor-m/inbox/entouch
# ../maildir/taylor-m/inbox/mary_schoen
# ../maildir/taylor-m/inbox/michelle_schultz
# ../maildir/taylor-m/inbox/trading_track
# ../maildir/taylor-m/inbox/training
# ../maildir/taylor-m/inbox/siegal
# ../maildir/taylor-m/inbox/archieves_coal_news
# ../maildir/taylor-m/s_a__trading
# ../maildir/taylor-m/kiodex
# ../maildir/taylor-m/online_trading
# ../maildir/taylor-m/online_trading/no_more_confirms
# ../maildir/taylor-m/online_trading/credit_derivatives
# ../maildir/taylor-m/online_trading/content
# ../maildir/taylor-m/online_trading/product_descriptions
# ../maildir/taylor-m/online_trading/eta_amendments
# ../maildir/taylor-m/australia_trading
# ../maildir/taylor-m/monmouth
# ../maildir/taylor-m/isda
# ../maildir/taylor-m/stored_messages
# ../maildir/taylor-m/click_at_home
# ../maildir/taylor-m/sent
# ../maildir/taylor-m/kelly
# ../maildir/taylor-m/restricted_list
# ../maildir/taylor-m/contacts
# ../maildir/taylor-m/indian_trading
# ../maildir/taylor-m/archive
# ../maildir/taylor-m/archive/9_00
# ../maildir/taylor-m/archive/5_00
# ../maildir/taylor-m/archive/11_99
# ../maildir/taylor-m/archive/2001_11
# ../maildir/taylor-m/archive/2_00
# ../maildir/taylor-m/archive/2001_09
# ../maildir/taylor-m/archive/2001_08
# ../maildir/taylor-m/archive/2001_10
# ../maildir/taylor-m/archive/2001_07
# ../maildir/taylor-m/archive/november1999
# ../maildir/taylor-m/archive/8_00
# ../maildir/taylor-m/archive/2001_06
# ../maildir/taylor-m/archive/6_00
# ../maildir/taylor-m/archive/7_00
# ../maildir/taylor-m/archive/2001_05
# ../maildir/taylor-m/archive/1_00
# ../maildir/taylor-m/boat
# ../maildir/taylor-m/sent_items
# ../maildir/taylor-m/travel
# ../maildir/taylor-m/singapore_trading
# ../maildir/taylor-m/oslo
# ../maildir/taylor-m/deleted_items
# ../maildir/taylor-m/tasks
# ../maildir/taylor-m/brazil_trading
# ../maildir/taylor-m/file_space
# ../maildir/taylor-m/time_off
# ../maildir/taylor-m/swap_group_project_lists
# ../maildir/meyers-a
# ../maildir/meyers-a/inbox
# ../maildir/meyers-a/sent_items
# ../maildir/meyers-a/deleted_items
# ../maildir/solberg-g
# ../maildir/solberg-g/info
# ../maildir/solberg-g/to_do
# ../maildir/solberg-g/inbox
# ../maildir/solberg-g/sent_items
# ../maildir/solberg-g/deleted_items
# ../maildir/solberg-g/tasks
# ../maildir/delainey-d
# ../maildir/delainey-d/all_documents
# ../maildir/delainey-d/notes_inbox
# ../maildir/delainey-d/inbox
# ../maildir/delainey-d/discussion_threads
# ../maildir/delainey-d/sent
# ../maildir/delainey-d/sent_items
# ../maildir/delainey-d/deleted_items
# ../maildir/delainey-d/_sent_mail
# ../maildir/dasovich-j
# ../maildir/dasovich-j/interconnection
# ../maildir/dasovich-j/mba__analysis_of_financial_information
# ../maildir/dasovich-j/benefits
# ../maildir/dasovich-j/general_rate_case_s_
# ../maildir/dasovich-j/all_documents
# ../maildir/dasovich-j/mba__accounting
# ../maildir/dasovich-j/legislation
# ../maildir/dasovich-j/risk_analytics
# ../maildir/dasovich-j/mba__e_commerce
# ../maildir/dasovich-j/mba__marketing
# ../maildir/dasovich-j/to_do
# ../maildir/dasovich-j/gas_accord
# ../maildir/dasovich-j/notes_inbox
# ../maildir/dasovich-j/commercial_opportunities_task_force
# ../maildir/dasovich-j/mba__quant
# ../maildir/dasovich-j/calendar
# ../maildir/dasovich-j/resco
# ../maildir/dasovich-j/edson
# ../maildir/dasovich-j/mba__managerial_accting
# ../maildir/dasovich-j/california_crisis
# ../maildir/dasovich-j/csu_fresno
# ../maildir/dasovich-j/cross_border_task_force
# ../maildir/dasovich-j/billing_issues
# ../maildir/dasovich-j/jennifer
# ../maildir/dasovich-j/telecom
# ../maildir/dasovich-j/inbox
# ../maildir/dasovich-j/inbox/direct_access_battle
# ../maildir/dasovich-j/california_crisis__press
# ../maildir/dasovich-j/budget
# ../maildir/dasovich-j/roseman_creek
# ../maildir/dasovich-j/natural_gas_strategy
# ../maildir/dasovich-j/personal
# ../maildir/dasovich-j/sent
# ../maildir/dasovich-j/ab_1890_group
# ../maildir/dasovich-j/magruder
# ../maildir/dasovich-j/administrative
# ../maildir/dasovich-j/boomerang
# ../maildir/dasovich-j/mexico
# ../maildir/dasovich-j/renewables
# ../maildir/dasovich-j/wptf
# ../maildir/dasovich-j/mba__macroeconomics
# ../maildir/dasovich-j/edwards_air_force
# ../maildir/dasovich-j/mba__advanced_finance
# ../maildir/dasovich-j/sent_items
# ../maildir/dasovich-j/mba__finance_study_group
# ../maildir/dasovich-j/ofos
# ../maildir/dasovich-j/gspp_conference
# ../maildir/dasovich-j/mba__finance
# ../maildir/dasovich-j/data
# ../maildir/dasovich-j/eci
# ../maildir/dasovich-j/distributed_generation
# ../maildir/dasovich-j/dell
# ../maildir/dasovich-j/water
# ../maildir/dasovich-j/mba__mpar
# ../maildir/dasovich-j/pg_e_hydro_sale
# ../maildir/dasovich-j/deleted_items
# ../maildir/dasovich-j/cfee
# ../maildir/dasovich-j/speeches
# ../maildir/dasovich-j/energymarketplace
# ../maildir/dasovich-j/pg_e_pbr
# ../maildir/dasovich-j/mba_program
# ../maildir/dasovich-j/mba__financial_reporting
# ../maildir/dasovich-j/press_releases
# ../maildir/dasovich-j/market_structure__task_force
# ../maildir/bailey-s
# ../maildir/bailey-s/all_documents
# ../maildir/bailey-s/notes_inbox
# ../maildir/bailey-s/inbox
# ../maildir/bailey-s/sent_items
# ../maildir/bailey-s/deleted_items
# ../maildir/salisbury-h
# ../maildir/salisbury-h/inbox
# ../maildir/salisbury-h/read
# ../maildir/salisbury-h/sent_items
# ../maildir/salisbury-h/deleted_items
# ../maildir/salisbury-h/holden_s
# ../maildir/schoolcraft-d
# ../maildir/schoolcraft-d/nng
# ../maildir/schoolcraft-d/tw_fuel_sales
# ../maildir/schoolcraft-d/tw_fuel_sales/tw_bullets
# ../maildir/schoolcraft-d/tw_fuel_sales/tw_bullets/tw_park___ride
# ../maildir/schoolcraft-d/cas
# ../maildir/schoolcraft-d/inbox
# ../maildir/schoolcraft-d/inbox/junk
# ../maildir/schoolcraft-d/inbox/citizens_griffith
# ../maildir/schoolcraft-d/tw
# ../maildir/schoolcraft-d/tw/tw_map
# ../maildir/schoolcraft-d/phffu
# ../maildir/schoolcraft-d/outages
# ../maildir/schoolcraft-d/outages/mileage_expense
# ../maildir/schoolcraft-d/tw_lft
# ../maildir/schoolcraft-d/untitled
# ../maildir/schoolcraft-d/sent_items
# ../maildir/schoolcraft-d/deleted_items
# ../maildir/schoolcraft-d/_sent_mail
# ../maildir/mccarty-d
# ../maildir/mccarty-d/to_do
# ../maildir/mccarty-d/calendar
# ../maildir/mccarty-d/inbox
# ../maildir/mccarty-d/inbox/2001_prc_ets_mid_year
# ../maildir/mccarty-d/inbox/nng
# ../maildir/mccarty-d/inbox/presentations
# ../maildir/mccarty-d/inbox/personnel
# ../maildir/mccarty-d/inbox/tw
# ../maildir/mccarty-d/inbox/2002_budget
# ../maildir/mccarty-d/inbox/transpecos
# ../maildir/mccarty-d/inbox/customers
# ../maildir/mccarty-d/inbox/personal
# ../maildir/mccarty-d/inbox/stupid_things
# ../maildir/mccarty-d/inbox/alaska_gas
# ../maildir/mccarty-d/inbox/asset_development
# ../maildir/mccarty-d/inbox/nbp
# ../maildir/mccarty-d/inbox/m_a
# ../maildir/mccarty-d/inbox/weekly_bullets
# ../maildir/mccarty-d/inbox/2001_objectives
# ../maildir/mccarty-d/inbox/merger
# ../maildir/mccarty-d/contacts
# ../maildir/mccarty-d/sent_items
# ../maildir/mccarty-d/deleted_items
# ../maildir/fossum-d
# ../maildir/fossum-d/all_documents
# ../maildir/fossum-d/notes_inbox
# ../maildir/fossum-d/discussion_threads
# ../maildir/fossum-d/sent
# ../maildir/fossum-d/favorites
# ../maildir/fossum-d/tasks
# ../maildir/fossum-d/_sent_mail
# ../maildir/rogers-b
# ../maildir/rogers-b/all_documents
# ../maildir/rogers-b/erc
# ../maildir/rogers-b/presentations
# ../maildir/rogers-b/notes_inbox
# ../maildir/rogers-b/ctg_deals
# ../maildir/rogers-b/inbox
# ../maildir/rogers-b/discussion_threads
# ../maildir/rogers-b/texas_b_school
# ../maildir/rogers-b/personal
# ../maildir/rogers-b/sent
# ../maildir/rogers-b/caledonia
# ../maildir/rogers-b/genco_jv_ipo
# ../maildir/rogers-b/enron_news
# ../maildir/rogers-b/sent_items
# ../maildir/rogers-b/enron_bike_club
# ../maildir/rogers-b/teco
# ../maildir/rogers-b/genco
# ../maildir/rogers-b/motley_fool_e_mails
# ../maildir/rogers-b/fpl_genco
# ../maildir/rogers-b/trading_info
# ../maildir/rogers-b/deleted_items
# ../maildir/rogers-b/kn_energy
# ../maildir/rogers-b/_sent_mail
# ../maildir/dean-c
# ../maildir/dean-c/info
# ../maildir/dean-c/all_documents
# ../maildir/dean-c/notes_inbox
# ../maildir/dean-c/inbox
# ../maildir/dean-c/discussion_threads
# ../maildir/dean-c/info3
# ../maildir/dean-c/sent
# ../maildir/dean-c/sent_items
# ../maildir/dean-c/deleted_items
# ../maildir/dean-c/info2
# ../maildir/dean-c/_sent_mail
# ../maildir/forney-j
# ../maildir/forney-j/to_do
# ../maildir/forney-j/inbox
# ../maildir/forney-j/sent_items
# ../maildir/forney-j/deleted_items
# ../maildir/forney-j/tasks
# ../maildir/donohoe-t
# ../maildir/donohoe-t/all_documents
# ../maildir/donohoe-t/notes_inbox
# ../maildir/donohoe-t/inbox
# ../maildir/donohoe-t/discussion_threads
# ../maildir/donohoe-t/sent
# ../maildir/donohoe-t/sent_items
# ../maildir/donohoe-t/deleted_items
# ../maildir/donohoe-t/_sent_mail
# ../maildir/keavey-p
# ../maildir/keavey-p/all_documents
# ../maildir/keavey-p/notes_inbox
# ../maildir/keavey-p/inbox
# ../maildir/keavey-p/discussion_threads
# ../maildir/keavey-p/sent
# ../maildir/keavey-p/contacts
# ../maildir/keavey-p/sent_items
# ../maildir/keavey-p/deleted_items
# ../maildir/keavey-p/saved_mail
# ../maildir/keavey-p/_sent_mail
# ../maildir/linder-e
# ../maildir/linder-e/all_documents
# ../maildir/linder-e/notes_inbox
# ../maildir/linder-e/discussion_threads
# ../maildir/linder-e/_sent_mail
# ../maildir/ruscitti-k
# ../maildir/ruscitti-k/benefits
# ../maildir/ruscitti-k/all_documents
# ../maildir/ruscitti-k/emailaddresses
# ../maildir/ruscitti-k/gas_deals
# ../maildir/ruscitti-k/to_do
# ../maildir/ruscitti-k/rotation
# ../maildir/ruscitti-k/notes_inbox
# ../maildir/ruscitti-k/nov00_mar01_deals
# ../maildir/ruscitti-k/billing_issues
# ../maildir/ruscitti-k/alliance
# ../maildir/ruscitti-k/options
# ../maildir/ruscitti-k/research
# ../maildir/ruscitti-k/inbox
# ../maildir/ruscitti-k/vector
# ../maildir/ruscitti-k/resume
# ../maildir/ruscitti-k/discussion_threads
# ../maildir/ruscitti-k/eol
# ../maildir/ruscitti-k/sent
# ../maildir/ruscitti-k/recruiting
# ../maildir/ruscitti-k/eol_rqsts
# ../maildir/ruscitti-k/company_options
# ../maildir/ruscitti-k/expense_system
# ../maildir/ruscitti-k/pictures
# ../maildir/ruscitti-k/sent_items
# ../maildir/ruscitti-k/travel
# ../maildir/ruscitti-k/resumes
# ../maildir/ruscitti-k/sithe
# ../maildir/ruscitti-k/michcon
# ../maildir/ruscitti-k/enron_dynegy
# ../maildir/ruscitti-k/deleted_items
# ../maildir/ruscitti-k/ces
# ../maildir/ruscitti-k/ml7_eol_product
# ../maildir/ruscitti-k/eolml7
# ../maildir/ruscitti-k/prc
# ../maildir/ruscitti-k/_sent_mail
# ../maildir/griffith-j
# ../maildir/griffith-j/monterrey_office
# ../maildir/griffith-j/national_steel
# ../maildir/griffith-j/benefits
# ../maildir/griffith-j/pseg
# ../maildir/griffith-j/black_hills
# ../maildir/griffith-j/skew
# ../maildir/griffith-j/perfomance_evaluation
# ../maildir/griffith-j/all_documents
# ../maildir/griffith-j/to_do
# ../maildir/griffith-j/move
# ../maildir/griffith-j/calendar
# ../maildir/griffith-j/vpp
# ../maildir/griffith-j/vpp/brazos_lp
# ../maildir/griffith-j/blotter
# ../maildir/griffith-j/fundamentals
# ../maildir/griffith-j/research
# ../maildir/griffith-j/design
# ../maildir/griffith-j/cqg
# ../maildir/griffith-j/transport
# ../maildir/griffith-j/system_wip
# ../maildir/griffith-j/inbox
# ../maildir/griffith-j/mesa
# ../maildir/griffith-j/day_rate
# ../maildir/griffith-j/continental
# ../maildir/griffith-j/personal_contacts
# ../maildir/griffith-j/dsc
# ../maildir/griffith-j/con_ed
# ../maildir/griffith-j/volatility
# ../maildir/griffith-j/indeck_corinth
# ../maildir/griffith-j/discussion_threads
# ../maildir/griffith-j/eol
# ../maildir/griffith-j/eol/clickathome
# ../maildir/griffith-j/mahonia
# ../maildir/griffith-j/ebay
# ../maildir/griffith-j/oyster_creek
# ../maildir/griffith-j/producer_services
# ../maildir/griffith-j/ft__pierce
# ../maildir/griffith-j/lng
# ../maildir/griffith-j/lng/supply
# ../maildir/griffith-j/lng/market
# ../maildir/griffith-j/lng/oman_supply
# ../maildir/griffith-j/personal
# ../maildir/griffith-j/coop_city
# ../maildir/griffith-j/stock_options
# ../maildir/griffith-j/new_items
# ../maildir/griffith-j/compression_services
# ../maildir/griffith-j/east_coast_power
# ../maildir/griffith-j/fpl
# ../maildir/griffith-j/position
# ../maildir/griffith-j/marsh_usa
# ../maildir/griffith-j/market
# ../maildir/griffith-j/ees
# ../maildir/griffith-j/golf
# ../maildir/griffith-j/sent_items
# ../maildir/griffith-j/insurance_call_spread
# ../maildir/griffith-j/newpower
# ../maildir/griffith-j/belden
# ../maildir/griffith-j/preston_vpp
# ../maildir/griffith-j/offshore_processing
# ../maildir/griffith-j/credit
# ../maildir/griffith-j/deleted_items
# ../maildir/griffith-j/deleted_items/eol_restored_by_exmerge_
# ../maildir/griffith-j/deleted_items/eol_restored_by_exmerge_/clickathome
# ../maildir/griffith-j/ice
# ../maildir/griffith-j/tasks
# ../maildir/griffith-j/funny
# ../maildir/griffith-j/private_folders
# ../maildir/griffith-j/private_folders/business
# ../maildir/griffith-j/private_folders/personal
# ../maildir/griffith-j/trading
# ../maildir/griffith-j/taxes
# ../maildir/griffith-j/clickathome
# ../maildir/griffith-j/ace
# ../maildir/griffith-j/enron_updates
# ../maildir/griffith-j/chase_mah_stone
# ../maildir/griffith-j/grupo_chihuahua
# ../maildir/griffith-j/cornhusker
# ../maildir/saibi-e
# ../maildir/saibi-e/saved
# ../maildir/saibi-e/all_documents
# ../maildir/saibi-e/notes_inbox
# ../maildir/saibi-e/calendar
# ../maildir/saibi-e/inbox
# ../maildir/saibi-e/discussion_threads
# ../maildir/saibi-e/sent_items
# ../maildir/saibi-e/deleted_items
# ../maildir/stepenovitch-j
# ../maildir/stepenovitch-j/all_documents
# ../maildir/stepenovitch-j/inbox
# ../maildir/stepenovitch-j/inbox/work_mail
# ../maildir/stepenovitch-j/inbox/personal_mail
# ../maildir/stepenovitch-j/discussion_threads
# ../maildir/stepenovitch-j/sent_items
# ../maildir/stepenovitch-j/deleted_items
# ../maildir/crandell-s
# ../maildir/crandell-s/to_do
# ../maildir/crandell-s/calendar
# ../maildir/crandell-s/inbox
# ../maildir/crandell-s/inbox/rto_west
# ../maildir/crandell-s/inbox/bankruptcy
# ../maildir/crandell-s/inbox/rto
# ../maildir/crandell-s/inbox/regulatory
# ../maildir/crandell-s/inbox/ubs
# ../maildir/crandell-s/inbox/ferc
# ../maildir/crandell-s/sent_items
# ../maildir/crandell-s/deleted_items
# ../maildir/wolfe-j
# ../maildir/wolfe-j/10_saved
# ../maildir/wolfe-j/all_documents
# ../maildir/wolfe-j/saved_01
# ../maildir/wolfe-j/calendar
# ../maildir/wolfe-j/saved_04
# ../maildir/wolfe-j/saved_03
# ../maildir/wolfe-j/saved_11
# ../maildir/wolfe-j/inbox
# ../maildir/wolfe-j/08_saved
# ../maildir/wolfe-j/09_saved
# ../maildir/wolfe-j/discussion_threads
# ../maildir/wolfe-j/06_saved
# ../maildir/wolfe-j/sent_items
# ../maildir/wolfe-j/saved_12
# ../maildir/wolfe-j/05_saved
# ../maildir/wolfe-j/deleted_items
# ../maildir/wolfe-j/saved_02
# ../maildir/wolfe-j/tasks
# ../maildir/wolfe-j/07_saved
# ../maildir/shively-h
# ../maildir/shively-h/all_documents
# ../maildir/shively-h/to_do
# ../maildir/shively-h/calendar
# ../maildir/shively-h/inbox
# ../maildir/shively-h/discussion_threads
# ../maildir/shively-h/sent
# ../maildir/shively-h/peoples_hedges
# ../maildir/shively-h/contacts
# ../maildir/shively-h/misc
# ../maildir/shively-h/sent_items
# ../maildir/shively-h/deleted_items
# ../maildir/shively-h/tasks
# ../maildir/shively-h/prc
# ../maildir/shively-h/_sent_mail
# ../maildir/schwieger-j
# ../maildir/schwieger-j/bammel_stg
# ../maildir/schwieger-j/credit_issues
# ../maildir/schwieger-j/all_documents
# ../maildir/schwieger-j/calendar
# ../maildir/schwieger-j/inbox
# ../maildir/schwieger-j/outbox
# ../maildir/schwieger-j/discussion_threads
# ../maildir/schwieger-j/personal
# ../maildir/schwieger-j/sent_items
# ../maildir/schwieger-j/deleted_items
# ../maildir/schwieger-j/hpl_sell
# ../maildir/gilbertsmith-d
# ../maildir/gilbertsmith-d/qse
# ../maildir/gilbertsmith-d/need_to_read
# ../maildir/gilbertsmith-d/expenses
# ../maildir/gilbertsmith-d/all_documents
# ../maildir/gilbertsmith-d/performance
# ../maildir/gilbertsmith-d/calendar
# ../maildir/gilbertsmith-d/fundamentals
# ../maildir/gilbertsmith-d/inbox
# ../maildir/gilbertsmith-d/personal
# ../maildir/gilbertsmith-d/sent_items
# ../maildir/gilbertsmith-d/deleted_items
# ../maildir/gilbertsmith-d/ercot
# ../maildir/gilbertsmith-d/ercot/qse
# ../maildir/gilbertsmith-d/ercot/origination
# ../maildir/gilbertsmith-d/ercot/loaddata
# ../maildir/gilbertsmith-d/ercot/recs
# ../maildir/gilbertsmith-d/ercot/fpl
# ../maildir/gilbertsmith-d/ercot/contacts
# ../maildir/gilbertsmith-d/ercot/transmission
# ../maildir/gilbertsmith-d/ercot/pricing
# ../maildir/gilbertsmith-d/ercot/puc
# ../maildir/gilbertsmith-d/ercot/mex_ppa
# ../maildir/tycholiz-b
# ../maildir/tycholiz-b/all_documents
# ../maildir/tycholiz-b/inbox
# ../maildir/tycholiz-b/discussion_threads
# ../maildir/tycholiz-b/sent
# ../maildir/tycholiz-b/westgas
# ../maildir/tycholiz-b/contacts
# ../maildir/tycholiz-b/sent_items
# ../maildir/tycholiz-b/deleted_items
# ../maildir/tycholiz-b/_sent_mail
# ../maildir/germany-c
# ../maildir/germany-c/pending
# ../maildir/germany-c/all_documents
# ../maildir/germany-c/traderr_tools
# ../maildir/germany-c/to_do
# ../maildir/germany-c/sap
# ../maildir/germany-c/notes_inbox
# ../maildir/germany-c/performance
# ../maildir/germany-c/calendar
# ../maildir/germany-c/ogelthorpe
# ../maildir/germany-c/transport
# ../maildir/germany-c/inbox
# ../maildir/germany-c/discussion_threads
# ../maildir/germany-c/ces_resolved
# ../maildir/germany-c/eol
# ../maildir/germany-c/personal
# ../maildir/germany-c/personal/kingdom
# ../maildir/germany-c/sent
# ../maildir/germany-c/new_power
# ../maildir/germany-c/takeover
# ../maildir/germany-c/appala
# ../maildir/germany-c/contacts
# ../maildir/germany-c/calp_hopewell
# ../maildir/germany-c/whatever
# ../maildir/germany-c/sent_items
# ../maildir/germany-c/vng
# ../maildir/germany-c/insideferc
# ../maildir/germany-c/bankrupt
# ../maildir/germany-c/bankrupt/bridgeline
# ../maildir/germany-c/bankrupt/aa____pending
# ../maildir/germany-c/bankrupt/tdc_energy
# ../maildir/germany-c/bankrupt/transport
# ../maildir/germany-c/bankrupt/transport/ngpl
# ../maildir/germany-c/bankrupt/transport/gulf_south
# ../maildir/germany-c/bankrupt/transport/columbia_gas_gulf
# ../maildir/germany-c/bankrupt/transport/transwestern
# ../maildir/germany-c/bankrupt/transport/union_gas
# ../maildir/germany-c/bankrupt/transport/trailblazer
# ../maildir/germany-c/bankrupt/transport/tennessee
# ../maildir/germany-c/bankrupt/transport/sonat
# ../maildir/germany-c/bankrupt/transport/iroquois
# ../maildir/germany-c/bankrupt/transport/mrt
# ../maildir/germany-c/bankrupt/transport/dominion
# ../maildir/germany-c/bankrupt/transport/appalachain
# ../maildir/germany-c/bankrupt/transport/colorado_intrastate
# ../maildir/germany-c/bankrupt/transport/password
# ../maildir/germany-c/bankrupt/transport/national_fuel
# ../maildir/germany-c/bankrupt/transport/northern_border
# ../maildir/germany-c/bankrupt/transport/transco
# ../maildir/germany-c/bankrupt/transport/centana_storage
# ../maildir/germany-c/bankrupt/transport/el_paso
# ../maildir/germany-c/bankrupt/transport/ena_upstream
# ../maildir/germany-c/bankrupt/cleburne_lone_star
# ../maildir/germany-c/bankrupt/enron_compressor_services
# ../maildir/germany-c/bankrupt/midland_cogen
# ../maildir/germany-c/bankrupt/tall_dominion
# ../maildir/germany-c/bankrupt/reliant_entex
# ../maildir/germany-c/bankrupt/sempra
# ../maildir/germany-c/bankrupt/juniper
# ../maildir/germany-c/bankrupt/enbridge
# ../maildir/germany-c/bankrupt/process
# ../maildir/germany-c/memos
# ../maildir/germany-c/systems
# ../maildir/germany-c/deleted_items
# ../maildir/germany-c/ces
# ../maildir/germany-c/tasks
# ../maildir/germany-c/ces_pending
# ../maildir/germany-c/book_issues
# ../maildir/germany-c/notes
# ../maildir/germany-c/notes/bankruptcy
# ../maildir/germany-c/notes/bankruptcy/florida_issues
# ../maildir/germany-c/_sent_mail
# ../maildir/merriss-s
# ../maildir/merriss-s/all_documents
# ../maildir/merriss-s/notes_inbox
# ../maildir/merriss-s/discussion_threads
# ../maildir/merriss-s/_sent_mail
# ../maildir/nemec-g
# ../maildir/nemec-g/all_documents
# ../maildir/nemec-g/to_do
# ../maildir/nemec-g/notes_inbox
# ../maildir/nemec-g/calendar
# ../maildir/nemec-g/inbox
# ../maildir/nemec-g/personal
# ../maildir/nemec-g/sent
# ../maildir/nemec-g/ca_data_sheet_checks
# ../maildir/nemec-g/vacation
# ../maildir/nemec-g/sent_items
# ../maildir/nemec-g/deleted_items
# ../maildir/nemec-g/tasks
# ../maildir/skilling-j
# ../maildir/skilling-j/all_documents
# ../maildir/skilling-j/notes_inbox
# ../maildir/skilling-j/calendar
# ../maildir/skilling-j/inbox
# ../maildir/skilling-j/inbox/genie
# ../maildir/skilling-j/discussion_threads
# ../maildir/skilling-j/sent
# ../maildir/skilling-j/contacts
# ../maildir/skilling-j/sent_items
# ../maildir/skilling-j/mark
# ../maildir/skilling-j/deleted_items
# ../maildir/skilling-j/_sent_mail
# ../maildir/steffes-j
# ../maildir/steffes-j/environmental
# ../maildir/steffes-j/credit_issues
# ../maildir/steffes-j/ontario_nug
# ../maildir/steffes-j/gu_recruiting
# ../maildir/steffes-j/2001_mid_year_prc
# ../maildir/steffes-j/spp
# ../maildir/steffes-j/wholesale_policy_reform
# ../maildir/steffes-j/to_do
# ../maildir/steffes-j/ga_fundamentals
# ../maildir/steffes-j/eisb_ubr
# ../maildir/steffes-j/cftc
# ../maildir/steffes-j/alliance_rto
# ../maildir/steffes-j/icap_policy
# ../maildir/steffes-j/pennsylvania
# ../maildir/steffes-j/inbox
# ../maildir/steffes-j/michigan
# ../maildir/steffes-j/aga_storage_report
# ../maildir/steffes-j/eol
# ../maildir/steffes-j/clinton_energy
# ../maildir/steffes-j/notre_dame
# ../maildir/steffes-j/rto
# ../maildir/steffes-j/illinois
# ../maildir/steffes-j/electric_reports
# ../maildir/steffes-j/california_issues
# ../maildir/steffes-j/california_issues/pnw_refunds
# ../maildir/steffes-j/california_issues/western_gas
# ../maildir/steffes-j/california_issues/ca_refunds
# ../maildir/steffes-j/ees_mgmt
# ../maildir/steffes-j/bush_transition
# ../maildir/steffes-j/nat_gas
# ../maildir/steffes-j/fed_legis_2001
# ../maildir/steffes-j/congress
# ../maildir/steffes-j/ferc_reporting_reqts
# ../maildir/steffes-j/granite_ii
# ../maildir/steffes-j/important_information
# ../maildir/steffes-j/competition_messages
# ../maildir/steffes-j/passwords
# ../maildir/steffes-j/contacts
# ../maildir/steffes-j/marketing_affiliate_matters
# ../maildir/steffes-j/arizona
# ../maildir/steffes-j/ferc
# ../maildir/steffes-j/ferc/ferc_mbr_proceeding
# ../maildir/steffes-j/ferc/ferc_gas_issues
# ../maildir/steffes-j/ferc/ferc_interconnection_anopr
# ../maildir/steffes-j/ferc/ferc_west_infrastructure
# ../maildir/steffes-j/ferc/ferc_reporting_reqts
# ../maildir/steffes-j/ferc/ferc_code_of_conduct_nopr
# ../maildir/steffes-j/ferc/ferc_westconnect
# ../maildir/steffes-j/gas_issues
# ../maildir/steffes-j/sent_items
# ../maildir/steffes-j/security___collateral
# ../maildir/steffes-j/midwest_retail_delivery
# ../maildir/steffes-j/show_cause
# ../maildir/steffes-j/texas
# ../maildir/steffes-j/us_sup_ct_case
# ../maildir/steffes-j/deleted_items
# ../maildir/steffes-j/mbr___market_power
# ../maildir/steffes-j/tasks
# ../maildir/steffes-j/nerc
# ../maildir/steffes-j/top_10_issues_6_1_01
# ../maildir/steffes-j/caem
# ../maildir/steffes-j/nevada
# ../maildir/steffes-j/structured_supply
# ../maildir/steffes-j/creditworthiness
# ../maildir/grigsby-m
# ../maildir/grigsby-m/all_documents
# ../maildir/grigsby-m/notes_inbox
# ../maildir/grigsby-m/inbox
# ../maildir/grigsby-m/discussion_threads
# ../maildir/grigsby-m/sent
# ../maildir/grigsby-m/contacts
# ../maildir/grigsby-m/sent_items
# ../maildir/grigsby-m/deleted_items
# ../maildir/grigsby-m/_sent_mail
# ../maildir/whalley-l
# ../maildir/whalley-l/all_documents
# ../maildir/whalley-l/notes_inbox
# ../maildir/whalley-l/discussion_threads
# ../maildir/whalley-l/sent
# ../maildir/whalley-l/contacts
# ../maildir/whalley-l/connect_deletes
# ../maildir/whalley-l/ecommerce
# ../maildir/whalley-l/tasks
# ../maildir/whalley-l/_sent_mail
# ../maildir/perlingiere-d
# ../maildir/perlingiere-d/all_documents
# ../maildir/perlingiere-d/notes_inbox
# ../maildir/perlingiere-d/calendar
# ../maildir/perlingiere-d/inbox
# ../maildir/perlingiere-d/richardson_s
# ../maildir/perlingiere-d/sent
# ../maildir/perlingiere-d/e_mail
# ../maildir/perlingiere-d/temporary_export_certificates
# ../maildir/perlingiere-d/sent_items
# ../maildir/perlingiere-d/new_normal_dot
# ../maildir/perlingiere-d/deleted_items
# ../maildir/phanis-s
# ../maildir/phanis-s/inbox
# ../maildir/phanis-s/contacts
# ../maildir/phanis-s/sent_items
# ../maildir/phanis-s/deleted_items
# ../maildir/ermis-f
# ../maildir/ermis-f/all_documents
# ../maildir/ermis-f/notes_inbox
# ../maildir/ermis-f/inbox
# ../maildir/ermis-f/discussion_threads
# ../maildir/ermis-f/sent
# ../maildir/ermis-f/sent_items
# ../maildir/ermis-f/deleted_items
# ../maildir/ermis-f/_sent_mail
# ../maildir/kean-s
# ../maildir/kean-s/interconnection
# ../maildir/kean-s/interconnection/interconnection
# ../maildir/kean-s/compensation
# ../maildir/kean-s/contributions
# ../maildir/kean-s/government_affairs_group_reports
# ../maildir/kean-s/ebs_redeployment
# ../maildir/kean-s/dod
# ../maildir/kean-s/internal_communications
# ../maildir/kean-s/canada
# ../maildir/kean-s/uniform_business_rules
# ../maildir/kean-s/western_governors
# ../maildir/kean-s/integration
# ../maildir/kean-s/integration/integration___team
# ../maildir/kean-s/mtbe
# ../maildir/kean-s/emerson
# ../maildir/kean-s/vision
# ../maildir/kean-s/internet_sites
# ../maildir/kean-s/europe
# ../maildir/kean-s/vision_and_values
# ../maildir/kean-s/bush
# ../maildir/kean-s/military_privatizations
# ../maildir/kean-s/all_documents
# ../maildir/kean-s/survey
# ../maildir/kean-s/governor_davis_meeting
# ../maildir/kean-s/transition_guide
# ../maildir/kean-s/gas
# ../maildir/kean-s/iowa
# ../maildir/kean-s/arena
# ../maildir/kean-s/management_conference
# ../maildir/kean-s/southern_cone
# ../maildir/kean-s/to_do
# ../maildir/kean-s/presentations
# ../maildir/kean-s/notes_inbox
# ../maildir/kean-s/compensation_and_benefits
# ../maildir/kean-s/working_groups
# ../maildir/kean-s/houston
# ../maildir/kean-s/bankruptcy
# ../maildir/kean-s/advertising
# ../maildir/kean-s/caliornia___investigations
# ../maildir/kean-s/knowledge_management
# ../maildir/kean-s/california___emergency_authority
# ../maildir/kean-s/metals
# ../maildir/kean-s/calendar
# ../maildir/kean-s/calendar/untitled
# ../maildir/kean-s/resco
# ../maildir/kean-s/campaign_2000
# ../maildir/kean-s/reports
# ../maildir/kean-s/wto
# ../maildir/kean-s/cftc
# ../maildir/kean-s/humor
# ../maildir/kean-s/dynegy_transaction
# ../maildir/kean-s/japan
# ../maildir/kean-s/california_campaign
# ../maildir/kean-s/non_us_offices
# ../maildir/kean-s/pr_crisis_management
# ../maildir/kean-s/enron_credit
# ../maildir/kean-s/pennsylvania
# ../maildir/kean-s/hr_data
# ../maildir/kean-s/updates
# ../maildir/kean-s/thank_yous
# ../maildir/kean-s/business_council
# ../maildir/kean-s/korea
# ../maildir/kean-s/inbox
# ../maildir/kean-s/inbox/enron_mentions
# ../maildir/kean-s/environmental_issues
# ../maildir/kean-s/personnel
# ../maildir/kean-s/staff_meeting
# ../maildir/kean-s/ofccp_audit
# ../maildir/kean-s/enron_online_summary
# ../maildir/kean-s/michigan
# ../maildir/kean-s/heat_wave
# ../maildir/kean-s/fire_chief
# ../maildir/kean-s/enron_communications
# ../maildir/kean-s/budget
# ../maildir/kean-s/position_papers
# ../maildir/kean-s/iso
# ../maildir/kean-s/trade_issues
# ../maildir/kean-s/resume
# ../maildir/kean-s/pac
# ../maildir/kean-s/discussion_threads
# ../maildir/kean-s/turkey
# ../maildir/kean-s/greenhouse_gas_business
# ../maildir/kean-s/security
# ../maildir/kean-s/california___working_group
# ../maildir/kean-s/ebr
# ../maildir/kean-s/advisory_board_on_electricity_and_the_environment
# ../maildir/kean-s/transportation_market
# ../maildir/kean-s/rto
# ../maildir/kean-s/cec_conference
# ../maildir/kean-s/pr___notre_dame
# ../maildir/kean-s/mit
# ../maildir/kean-s/illinois
# ../maildir/kean-s/personal
# ../maildir/kean-s/project_summer
# ../maildir/kean-s/enron_mentions
# ../maildir/kean-s/corporate_responsibility
# ../maildir/kean-s/world_bank
# ../maildir/kean-s/sent
# ../maildir/kean-s/organization
# ../maildir/kean-s/aadepartment
# ../maildir/kean-s/enrononline
# ../maildir/kean-s/resource_management
# ../maildir/kean-s/bush_transition
# ../maildir/kean-s/fuel_cells
# ../maildir/kean-s/tax_issues
# ../maildir/kean-s/washington_office
# ../maildir/kean-s/sec
# ../maildir/kean-s/california___excess_profits_tax
# ../maildir/kean-s/india
# ../maildir/kean-s/goals_and_objectives_1999
# ../maildir/kean-s/gore
# ../maildir/kean-s/market_structure
# ../maildir/kean-s/administrative
# ../maildir/kean-s/federal_emergency
# ../maildir/kean-s/experience_enron
# ../maildir/kean-s/mckinsey_project
# ../maildir/kean-s/hr_stats
# ../maildir/kean-s/pge
# ../maildir/kean-s/university_relations
# ../maildir/kean-s/west_virginia
# ../maildir/kean-s/disclosure_rules
# ../maildir/kean-s/electricity_restructuring_advisory_group
# ../maildir/kean-s/bpa
# ../maildir/kean-s/cuiba
# ../maildir/kean-s/mexico
# ../maildir/kean-s/environment___montreal
# ../maildir/kean-s/y2k
# ../maildir/kean-s/rail
# ../maildir/kean-s/hr
# ../maildir/kean-s/junk_mail
# ../maildir/kean-s/enron_litigation
# ../maildir/kean-s/california_pg_e_bankruptcy
# ../maildir/kean-s/ees
# ../maildir/kean-s/ferc
# ../maildir/kean-s/california___demand_buydown
# ../maildir/kean-s/sent_items
# ../maildir/kean-s/unions
# ../maildir/kean-s/archiving
# ../maildir/kean-s/archiving/untitled
# ../maildir/kean-s/attachments
# ../maildir/kean-s/azurix
# ../maildir/kean-s/senate_testimony_re_california
# ../maildir/kean-s/project_california
# ../maildir/kean-s/enron_global_markets
# ../maildir/kean-s/ui
# ../maildir/kean-s/analyst_associate_program
# ../maildir/kean-s/mergers
# ../maildir/kean-s/cost_controls
# ../maildir/kean-s/reg_risk
# ../maildir/kean-s/new_york
# ../maildir/kean-s/networks
# ../maildir/kean-s/annual_report
# ../maildir/kean-s/enron_property_services
# ../maildir/kean-s/california_humor
# ../maildir/kean-s/performance_management
# ../maildir/kean-s/argentina
# ../maildir/kean-s/texas
# ../maildir/kean-s/aviation
# ../maildir/kean-s/redeployment
# ../maildir/kean-s/transco
# ../maildir/kean-s/tva
# ../maildir/kean-s/rice
# ../maildir/kean-s/deleted_items
# ../maildir/kean-s/deleted_items/gas
# ../maildir/kean-s/deleted_items/mexico
# ../maildir/kean-s/deleted_items/mexico/market_structure
# ../maildir/kean-s/deleted_items/press
# ../maildir/kean-s/africa
# ../maildir/kean-s/africa/enron_accelerator
# ../maildir/kean-s/speeches
# ../maildir/kean-s/republican_leadership
# ../maildir/kean-s/enron_advisonry_council
# ../maildir/kean-s/councilforeignrelations
# ../maildir/kean-s/antitrust
# ../maildir/kean-s/analyst_meeting_2001
# ../maildir/kean-s/federal_legislation
# ../maildir/kean-s/earnings_releases
# ../maildir/kean-s/florida
# ../maildir/kean-s/nerc
# ../maildir/kean-s/nacec
# ../maildir/kean-s/crisis
# ../maildir/kean-s/corporate_communications
# ../maildir/kean-s/prc
# ../maildir/kean-s/facilities_services
# ../maildir/kean-s/ohio
# ../maildir/kean-s/opic
# ../maildir/kean-s/ljm
# ../maildir/kean-s/pipeline_issues
# ../maildir/kean-s/affiliate_rules
# ../maildir/kean-s/press_releases
# ../maildir/kean-s/puhca
# ../maildir/kean-s/california
# ../maildir/kean-s/california/ballot_initiative
# ../maildir/kean-s/asset_sales
# ../maildir/kean-s/international
# ../maildir/kean-s/press
# ../maildir/kean-s/transredes
# ../maildir/kean-s/contact_list
# ../maildir/lavorato-j
# ../maildir/lavorato-j/canada
# ../maildir/lavorato-j/all_documents
# ../maildir/lavorato-j/gas
# ../maildir/lavorato-j/to_do
# ../maildir/lavorato-j/notes_inbox
# ../maildir/lavorato-j/calendar
# ../maildir/lavorato-j/powereast
# ../maildir/lavorato-j/transport
# ../maildir/lavorato-j/controls
# ../maildir/lavorato-j/inbox
# ../maildir/lavorato-j/analyst_associate
# ../maildir/lavorato-j/discussion_threads
# ../maildir/lavorato-j/southamerica
# ../maildir/lavorato-j/jean
# ../maildir/lavorato-j/personal
# ../maildir/lavorato-j/sent
# ../maildir/lavorato-j/old_inbox
# ../maildir/lavorato-j/comp
# ../maildir/lavorato-j/sent_items
# ../maildir/lavorato-j/weather
# ../maildir/lavorato-j/_hedgefunds
# ../maildir/lavorato-j/var
# ../maildir/lavorato-j/powerwest
# ../maildir/lavorato-j/systems
# ../maildir/lavorato-j/deleted_items
# ../maildir/lavorato-j/coal
# ../maildir/lavorato-j/prc
# ../maildir/lavorato-j/offsite
# ../maildir/lavorato-j/phone_numbers
# ../maildir/lavorato-j/california
# ../maildir/lavorato-j/ecr
# ../maildir/lavorato-j/pulp
# ../maildir/lavorato-j/_sent_mail
# ../maildir/tholt-j
# ../maildir/tholt-j/all_documents
# ../maildir/tholt-j/notes_inbox
# ../maildir/tholt-j/inbox
# ../maildir/tholt-j/discussion_threads
# ../maildir/tholt-j/sent
# ../maildir/tholt-j/sent_items
# ../maildir/tholt-j/janie
# ../maildir/tholt-j/deleted_items
# ../maildir/tholt-j/_sent_mail
# ../maildir/mclaughlin-e
# ../maildir/mclaughlin-e/eol___tagg
# ../maildir/mclaughlin-e/all_documents
# ../maildir/mclaughlin-e/prepays_structured_deals
# ../maildir/mclaughlin-e/notes_inbox
# ../maildir/mclaughlin-e/calendar
# ../maildir/mclaughlin-e/inbox
# ../maildir/mclaughlin-e/gossett
# ../maildir/mclaughlin-e/greg_couch
# ../maildir/mclaughlin-e/discussion_threads
# ../maildir/mclaughlin-e/sent
# ../maildir/mclaughlin-e/contacts
# ../maildir/mclaughlin-e/sent_items
# ../maildir/mclaughlin-e/security_request
# ../maildir/mclaughlin-e/deleted_items
# ../maildir/mclaughlin-e/tasks
# ../maildir/mclaughlin-e/monthly_pma_s
# ../maildir/mclaughlin-e/private_folders
# ../maildir/mclaughlin-e/private_folders/monthly_dpr_adjustments
# ../maildir/mclaughlin-e/private_folders/corp_info_announcements
# ../maildir/mclaughlin-e/private_folders/personal_stuff
# ../maildir/mclaughlin-e/_sent_mail
# ../maildir/south-s
# ../maildir/south-s/all_documents
# ../maildir/south-s/southern_cone
# ../maildir/south-s/notes_inbox
# ../maildir/south-s/discussion_threads
# ../maildir/south-s/sent
# ../maildir/south-s/southeast
# ../maildir/south-s/_sent_mail
# ../maildir/ybarbo-p
# ../maildir/ybarbo-p/oman_lng
# ../maildir/ybarbo-p/transwestern
# ../maildir/ybarbo-p/all_documents
# ../maildir/ybarbo-p/calendar
# ../maildir/ybarbo-p/enron_lng
# ../maildir/ybarbo-p/cabot
# ../maildir/ybarbo-p/dabhol
# ../maildir/ybarbo-p/eco___cond__of_use
# ../maildir/ybarbo-p/dabhol___cond__of_use
# ../maildir/ybarbo-p/inbox
# ../maildir/ybarbo-p/discussion_threads
# ../maildir/ybarbo-p/ad_gas
# ../maildir/ybarbo-p/sent
# ...
# ../maildir/lokay-m
# ../maildir/lokay-m/all_documents
# ../maildir/lokay-m/notes_inbox
# ../maildir/lokay-m/enron_t_s
# ../maildir/lokay-m/publications
# ../maildir/lokay-m/lorraine_s_files
# ../maildir/lokay-m/inbox
# ../maildir/lokay-m/enron_travel_club
# ../maildir/lokay-m/hea_nesa
# ../maildir/lokay-m/discussion_threads
# ../maildir/lokay-m/articles
# ../maildir/lokay-m/personal
# ../maildir/lokay-m/sent
# ../maildir/lokay-m/kim_s_files
# ../maildir/lokay-m/contacts
# ../maildir/lokay-m/tw_commercial_group
# ../maildir/lokay-m/sent_items
# ../maildir/lokay-m/training
# ../maildir/lokay-m/corporate
# ../maildir/lokay-m/systems
# ../maildir/lokay-m/deleted_items
# ../maildir/lokay-m/_sent_mail
# ../maildir/weldon-c
# ../maildir/weldon-c/project_orange
# ../maildir/weldon-c/freestone
# ../maildir/weldon-c/citibank
# ../maildir/weldon-c/friends
# ../maildir/weldon-c/highland
# ../maildir/weldon-c/all_documents
# ../maildir/weldon-c/unocal
# ../maildir/weldon-c/misc__gas_issues
# ../maildir/weldon-c/calendar
# ../maildir/weldon-c/inbox
# ../maildir/weldon-c/inbox/ubs
# ../maildir/weldon-c/inbox/trading
# ../maildir/weldon-c/ut_mba
# ../maildir/weldon-c/neumin
# ../maildir/weldon-c/discussion_threads
# ../maildir/weldon-c/eol
# ../maildir/weldon-c/ft__pierce
# ../maildir/weldon-c/associate
# ../maildir/weldon-c/lng
# ../maildir/weldon-c/sent
# ../maildir/weldon-c/misc_
# ../maildir/weldon-c/kern
# ../maildir/weldon-c/austin_energy
# ../maildir/weldon-c/southern_lng
# ../maildir/weldon-c/stagecoach
# ../maildir/weldon-c/contacts
# ../maildir/weldon-c/sent_items
# ../maildir/weldon-c/national_fuel
# ../maildir/weldon-c/training
# ../maildir/weldon-c/ed
# ../maildir/weldon-c/rotation_1
# ../maildir/weldon-c/rotation_1/hurricane
# ../maildir/weldon-c/rotation_1/ja
# ../maildir/weldon-c/rotation_1/water
# ../maildir/weldon-c/rotation_1/water/ag_model
# ../maildir/weldon-c/abraxas
# ../maildir/weldon-c/midway
# ../maildir/weldon-c/kcs
# ../maildir/weldon-c/deleted_items
# ../maildir/weldon-c/it
# ../maildir/weldon-c/private_folders
# ../maildir/weldon-c/private_folders/associate
# ../maildir/weldon-c/prc
# ../maildir/weldon-c/_sent_mail
# ../maildir/stokley-c
# ../maildir/stokley-c/chris_stokley
# ../maildir/stokley-c/chris_stokley/enron_corp
# ../maildir/stokley-c/chris_stokley/projects
# ../maildir/stokley-c/chris_stokley/projects/ees_
# ../maildir/stokley-c/chris_stokley/projects/ees_/brenda_herod
# ../maildir/stokley-c/chris_stokley/projects/ees_/info
# ../maildir/stokley-c/chris_stokley/projects/ees_/intr_month_book
# ../maildir/stokley-c/chris_stokley/projects/ees_/metering_and_forcasting
# ../maildir/stokley-c/chris_stokley/projects/ees_/banding
# ../maildir/stokley-c/chris_stokley/projects/ees_/banding/kpmg
# ../maildir/stokley-c/chris_stokley/projects/ees_/todd_busby
# ../maildir/stokley-c/chris_stokley/projects/ees_/neil_b_
# ../maildir/stokley-c/chris_stokley/projects/ees_/ercot
# ../maildir/stokley-c/chris_stokley/projects/sqmd
# ../maildir/stokley-c/chris_stokley/projects/ees
# ../maildir/stokley-c/chris_stokley/murray
# ../maildir/stokley-c/chris_stokley/volume_mang_
# ../maildir/stokley-c/chris_stokley/iso
# ../maildir/stokley-c/chris_stokley/iso/info
# ../maildir/stokley-c/chris_stokley/iso/mrkt_info
# ../maildir/stokley-c/chris_stokley/iso/client_rep
# ../maildir/stokley-c/chris_stokley/regulatory
# ../maildir/stokley-c/chris_stokley/sent
# ../maildir/stokley-c/chris_stokley/mid_markt
# ../maildir/watson-k
# ../maildir/watson-k/girls
# ../maildir/watson-k/negotiated_rates
# ../maildir/watson-k/mike_reynolds
# ../maildir/watson-k/sun_devil_expansion
# ../maildir/watson-k/nng
# ../maildir/watson-k/pba_s
# ../maildir/watson-k/credit_union
# ../maildir/watson-k/alternate_delivery_by_price
# ../maildir/watson-k/keyex_1997
# ../maildir/watson-k/tw_options_sales_program
# ../maildir/watson-k/nymex_prices
# ../maildir/watson-k/rm_work_order
# ../maildir/watson-k/sap
# ../maildir/watson-k/interconnect_agreement_sample
# ../maildir/watson-k/kingman_heat_recovery
# ../maildir/watson-k/operational_sales
# ../maildir/watson-k/tw_rate_matrix
# ../maildir/watson-k/top_shippers
# ../maildir/watson-k/strategic_model
# ../maildir/watson-k/pros
# ../maildir/watson-k/inbox
# ../maildir/watson-k/holidays
# ../maildir/watson-k/payroll_electronic_directions
# ../maildir/watson-k/vinson___elkins
# ../maildir/watson-k/citizens
# ../maildir/watson-k/desert_crossing_storage
# ../maildir/watson-k/on_call_schedule
# ../maildir/watson-k/drafts__lotus_notes_
# ../maildir/watson-k/daily_balancing_report
# ../maildir/watson-k/contact_emp__list
# ../maildir/watson-k/enron_online
# ../maildir/watson-k/rm_science_review
# ../maildir/watson-k/customer_list
# ../maildir/watson-k/dra
# ../maildir/watson-k/tw_imbalances
# ../maildir/watson-k/business_objects
# ../maildir/watson-k/order_637
# ../maildir/watson-k/aquila_red_lake_storage
# ../maildir/watson-k/tw_cas
# ../maildir/watson-k/questar
# ../maildir/watson-k/capacity
# ../maildir/watson-k/elpaso_pipeline
# ../maildir/watson-k/e_mail_bin
# ../maildir/watson-k/gri_jan_1996
# ../maildir/watson-k/account_assignments
# ../maildir/watson-k/italy
# ../maildir/watson-k/industry_mentions
# ../maildir/watson-k/usgt
# ../maildir/watson-k/ethink
# ../maildir/watson-k/san_juan_expansion
# ../maildir/watson-k/pemex_trans_pecos
# ../maildir/watson-k/agave
# ../maildir/watson-k/big_sandy___caithness
# ../maildir/watson-k/paris
# ../maildir/watson-k/sent_items
# ../maildir/watson-k/weather
# ../maildir/watson-k/tw_weekly_report
# ../maildir/watson-k/red_rock
# ../maildir/watson-k/tw_throughput_analysis
# ../maildir/watson-k/expense_rpts__1997
# ../maildir/watson-k/tw_outages
# ../maildir/watson-k/capacity_release
# ../maildir/watson-k/socalgas
# ../maildir/watson-k/glen_hass
# ../maildir/watson-k/deleted_items
# ../maildir/watson-k/park__n_ride
# ../maildir/watson-k/funny
# ../maildir/watson-k/california
# ../maildir/watson-k/tw_hedges
# ../maildir/mckay-j
# ../maildir/mckay-j/to_do
# ../maildir/mckay-j/calendar
# ../maildir/mckay-j/pipeinfo
# ../maildir/mckay-j/ubswenergy_com
# ../maildir/mckay-j/inbox
# ../maildir/mckay-j/ne_development
# ../maildir/mckay-j/quotes
# ../maildir/mckay-j/quotes/not_printed
# ../maildir/mckay-j/pipeline_info
# ../maildir/mckay-j/recuriting
# ../maildir/mckay-j/personal
# ../maildir/mckay-j/enron
# ../maildir/mckay-j/contacts
# ../maildir/mckay-j/sent_items
# ../maildir/mckay-j/perfmgmt
# ../maildir/mckay-j/ubs_warburg
# ../maildir/mckay-j/deleted_items
# ../maildir/mckay-j/tasks
# ../maildir/mckay-j/retail
# ../maildir/williams-j
# ../maildir/williams-j/commoditylogic
# ../maildir/williams-j/all_documents
# ../maildir/williams-j/inbox
# ../maildir/williams-j/discussion_threads
# ../maildir/williams-j/6day
# ../maildir/williams-j/legal
# ../maildir/williams-j/sent_items
# ../maildir/williams-j/deals
# ../maildir/williams-j/deleted_items
# ../maildir/williams-j/private_folders
# ../maildir/williams-j/private_folders/jays_stuff
# ../maildir/williams-j/private_folders/passwords
# ../maildir/shapiro-r
# ../maildir/shapiro-r/value
# ../maildir/shapiro-r/contributions
# ../maildir/shapiro-r/europe_july
# ../maildir/shapiro-r/interconnection_issues
# ../maildir/shapiro-r/new_england_ny
# ../maildir/shapiro-r/canada
# ../maildir/shapiro-r/wholesale_markets
# ../maildir/shapiro-r/midwest
# ../maildir/shapiro-r/investing
# ../maildir/shapiro-r/california_coverup
# ../maildir/shapiro-r/europe
# ../maildir/shapiro-r/all_documents
# ../maildir/shapiro-r/risk_analytics
# ../maildir/shapiro-r/southern_cone
# ../maildir/shapiro-r/presentations
# ../maildir/shapiro-r/notes_inbox
# ../maildir/shapiro-r/sce_deal
# ../maildir/shapiro-r/pg_e_bankruptcy
# ../maildir/shapiro-r/federal_gov_t_affairs
# ../maildir/shapiro-r/compliments
# ../maildir/shapiro-r/refund_cases
# ../maildir/shapiro-r/cftc
# ../maildir/shapiro-r/staff_meetings
# ../maildir/shapiro-r/fundamentals
# ../maildir/shapiro-r/vp_prc
# ../maildir/shapiro-r/personal_travel
# ../maildir/shapiro-r/humor
# ../maildir/shapiro-r/congrats
# ../maildir/shapiro-r/japan
# ../maildir/shapiro-r/organizational_issues
# ../maildir/shapiro-r/resource_committment_req_s
# ../maildir/shapiro-r/europe_june
# ../maildir/shapiro-r/associations
# ../maildir/shapiro-r/affiliate_codes_of_conduct
# ../maildir/shapiro-r/rto_campaign
# ../maildir/shapiro-r/rto_campaign/show_cause_motion
# ../maildir/shapiro-r/inbox
# ../maildir/shapiro-r/mid_atlantic
# ../maildir/shapiro-r/market_structure__seabron_adamson_
# ../maildir/shapiro-r/personnel
# ../maildir/shapiro-r/patriotism
# ../maildir/shapiro-r/europe_october
# ../maildir/shapiro-r/west
# ../maildir/shapiro-r/forest_and_paper_products
# ../maildir/shapiro-r/retail_markets
# ../maildir/shapiro-r/california_legal_issues
# ../maildir/shapiro-r/discussion_threads
# ../maildir/shapiro-r/2002_budget
# ../maildir/shapiro-r/2002_budget/2001_budget
# ../maildir/shapiro-r/epsa
# ../maildir/shapiro-r/federal_legis_
# ../maildir/shapiro-r/enron_online
# ../maildir/shapiro-r/global_markets
# ../maildir/shapiro-r/notre_dame
# ../maildir/shapiro-r/qf_s___risk_analysis
# ../maildir/shapiro-r/doe
# ../maildir/shapiro-r/merchant_function_group
# ../maildir/shapiro-r/retail_operations
# ../maildir/shapiro-r/hedging
# ../maildir/shapiro-r/shopping
# ../maildir/shapiro-r/lng
# ../maildir/shapiro-r/personal
# ../maildir/shapiro-r/sent
# ../maildir/shapiro-r/rto_filings__order_2000
# ../maildir/shapiro-r/fuel_cells
# ../maildir/shapiro-r/democrats
# ../maildir/shapiro-r/southeast
# ../maildir/shapiro-r/sec
# ../maildir/shapiro-r/india
# ../maildir/shapiro-r/pge_sale
# ../maildir/shapiro-r/synfuel_tax_crredits
# ../maildir/shapiro-r/western_governor_s_university
# ../maildir/shapiro-r/mexico
# ../maildir/shapiro-r/policy_papers
# ../maildir/shapiro-r/granite__2_
# ../maildir/shapiro-r/rac
# ../maildir/shapiro-r/rail
# ../maildir/shapiro-r/media
# ../maildir/shapiro-r/ferc
# ../maildir/shapiro-r/enviromental
# ../maildir/shapiro-r/naruc
# ../maildir/shapiro-r/gas_issues
# ../maildir/shapiro-r/sent_items
# ../maildir/shapiro-r/generation
# ../maildir/shapiro-r/generation/europe_august
# ../maildir/shapiro-r/computers
# ../maildir/shapiro-r/bush_administration
# ../maildir/shapiro-r/default_service__opportunities
# ../maildir/shapiro-r/networks
# ../maildir/shapiro-r/ken_lay
# ../maildir/shapiro-r/steel
# ../maildir/shapiro-r/texas
# ../maildir/shapiro-r/venezuela_colombia
# ../maildir/shapiro-r/training__gov_t__affairs
# ../maildir/shapiro-r/tva
# ../maildir/shapiro-r/industrial_cust__solutions
# ../maildir/shapiro-r/deleted_items
# ../maildir/shapiro-r/deleted_items/resource_committment_req_s
# ../maildir/shapiro-r/deleted_items/patriotism
# ../maildir/shapiro-r/deleted_items/caem
# ../maildir/shapiro-r/2001_prc__midyear
# ../maildir/shapiro-r/coal
# ../maildir/shapiro-r/broadband_services
# ../maildir/shapiro-r/antitrust
# ../maildir/shapiro-r/2001_witchunt
# ../maildir/shapiro-r/florida
# ../maildir/shapiro-r/nerc
# ../maildir/shapiro-r/national_campaign
# ../maildir/shapiro-r/caem
# ../maildir/shapiro-r/speaking_engagements
# ../maildir/shapiro-r/tax
# ../maildir/shapiro-r/2001_budget
# ../maildir/shapiro-r/2001_objectives
# ../maildir/shapiro-r/california
# ../maildir/shapiro-r/2001_budget__cost_cutting
# ../maildir/shapiro-r/price_risk_management_
# ../maildir/mcconnell-m
# ../maildir/mcconnell-m/webmodal
# ../maildir/mcconnell-m/puerto_rico
# ../maildir/mcconnell-m/misc_tw
# ../maildir/mcconnell-m/julie_ferrara
# ../maildir/mcconnell-m/freight
# ../maildir/mcconnell-m/all_documents
# ../maildir/mcconnell-m/art
# ../maildir/mcconnell-m/to_do
# ../maildir/mcconnell-m/presentations
# ../maildir/mcconnell-m/notes_inbox
# ../maildir/mcconnell-m/project_grandslam
# ../maildir/mcconnell-m/ou
# ../maildir/mcconnell-m/project_dolphin
# ../maildir/mcconnell-m/project_jose
# ../maildir/mcconnell-m/metals
# ../maildir/mcconnell-m/calendar
# ../maildir/mcconnell-m/garcia_munte
# ../maildir/mcconnell-m/atlantis
# ../maildir/mcconnell-m/japan
# ../maildir/mcconnell-m/s_america
# ../maildir/mcconnell-m/crude_and_products
# ../maildir/mcconnell-m/house
# ../maildir/mcconnell-m/enroncredit_com
# ../maildir/mcconnell-m/inbox
# ../maildir/mcconnell-m/insurance_risk
# ../maildir/mcconnell-m/discussion_threads
# ../maildir/mcconnell-m/jblock
# ../maildir/mcconnell-m/supply_chain
# ../maildir/mcconnell-m/articles
# ../maildir/mcconnell-m/lng
# ../maildir/mcconnell-m/personal
# ../maildir/mcconnell-m/house___new
# ../maildir/mcconnell-m/project_springbok
# ../maildir/mcconnell-m/sent
# ../maildir/mcconnell-m/gaza
# ../maildir/mcconnell-m/vision___values
# ../maildir/mcconnell-m/india
# ../maildir/mcconnell-m/investments
# ../maildir/mcconnell-m/i2
# ../maildir/mcconnell-m/contacts
# ../maildir/mcconnell-m/legal
# ../maildir/mcconnell-m/first_gas
# ../maildir/mcconnell-m/middle_east
# ../maildir/mcconnell-m/ees
# ../maildir/mcconnell-m/misc
# ../maildir/mcconnell-m/misc/misc_vod
# ../maildir/mcconnell-m/misc/misc_vod/games_music
# ../maildir/mcconnell-m/misc/misc_vod/switchpoint
# ../maildir/mcconnell-m/misc/misc_vod/bell_south
# ../maildir/mcconnell-m/misc/admin_assist
# ../maildir/mcconnell-m/connect_deletes
# ../maildir/mcconnell-m/sent_items
# ../maildir/mcconnell-m/weather
# ../maildir/mcconnell-m/var
# ../maildir/mcconnell-m/synfuel
# ../maildir/mcconnell-m/enhome
# ../maildir/mcconnell-m/transamonia
# ../maildir/mcconnell-m/tw_accounts
# ../maildir/mcconnell-m/tw_accounts/pepl
# ../maildir/mcconnell-m/tw_accounts/lonestar
# ../maildir/mcconnell-m/tw_accounts/aquila
# ../maildir/mcconnell-m/tw_accounts/us_gypsum
# ../maildir/mcconnell-m/tw_accounts/usgt
# ../maildir/mcconnell-m/tw_accounts/conoco
# ../maildir/mcconnell-m/tw_accounts/astra
# ../maildir/mcconnell-m/saudi_arabia_project
# ../maildir/mcconnell-m/art_committee
# ../maildir/mcconnell-m/deleted_items
# ../maildir/mcconnell-m/coal
# ../maildir/mcconnell-m/tasks
# ../maildir/mcconnell-m/tw_projects
# ../maildir/mcconnell-m/tw_projects/misc_tie_ins
# ../maildir/mcconnell-m/tw_projects/trans_pecos
# ../maildir/mcconnell-m/tw_projects/southern_trails
# ../maildir/mcconnell-m/tw_projects/agave_tie_in
# ../maildir/mcconnell-m/org__announc_
# ../maildir/mcconnell-m/dpc_lng
# ../maildir/mcconnell-m/project_sato
# ../maildir/mcconnell-m/bergseiker
# ../maildir/mcconnell-m/jdf
# ../maildir/mcconnell-m/_sent_mail
# ../maildir/kuykendall-t
# ../maildir/kuykendall-t/friends
# ../maildir/kuykendall-t/all_documents
# ../maildir/kuykendall-t/notes_inbox
# ../maildir/kuykendall-t/inbox
# ../maildir/kuykendall-t/discussion_threads
# ../maildir/kuykendall-t/sent
# ../maildir/kuykendall-t/sent_items
# ../maildir/kuykendall-t/deleted_items
# ../maildir/kuykendall-t/_sent_mail
# ../maildir/campbell-l
# ../maildir/campbell-l/pcb_s
# ../maildir/campbell-l/la_plata_c_s
# ../maildir/campbell-l/ngo_s
# ../maildir/campbell-l/lockridge_remediation
# ../maildir/campbell-l/npdes_stormwater
# ../maildir/campbell-l/all_documents
# ../maildir/campbell-l/eott_due_diligence
# ../maildir/campbell-l/njn
# ../maildir/campbell-l/c_s_no__6_remediation
# ../maildir/campbell-l/notes_inbox
# ../maildir/campbell-l/et_contacts
# ../maildir/campbell-l/southwest_gas_pcb_s
# ../maildir/campbell-l/p_1_c_s_nov
# ../maildir/campbell-l/pg_e_meetings_and_notes
# ../maildir/campbell-l/personnal
# ../maildir/campbell-l/inbox
# ../maildir/campbell-l/public_water_systems
# ../maildir/campbell-l/eott_midland
# ../maildir/campbell-l/weekly_activity_report
# ../maildir/campbell-l/discussion_threads
# ../maildir/campbell-l/marc_phillips
# ../maildir/campbell-l/2001_goals_and_objectives
# ../maildir/campbell-l/sent
# ../maildir/campbell-l/pfg
# ../maildir/campbell-l/ocd
# ../maildir/campbell-l/importantstuff
# ../maildir/campbell-l/redrock_mainline_expansion
# ../maildir/campbell-l/et
# ../maildir/campbell-l/et/cge
# ../maildir/campbell-l/pcb_modeling_study
# ../maildir/campbell-l/atoka_3_c_s
# ../maildir/campbell-l/euncie_texaco_remediation
# ../maildir/campbell-l/nyiso
# ../maildir/campbell-l/contacts
# ../maildir/campbell-l/2000_goals_and_objectives
# ../maildir/campbell-l/socal_pcb_s
# ../maildir/campbell-l/sent_items
# ../maildir/campbell-l/gomez_remediation
# ../maildir/campbell-l/pg_e_pcbs
# ../maildir/campbell-l/puckett_plant
# ../maildir/campbell-l/diamonds
# ../maildir/campbell-l/bloomfield_c_s
# ../maildir/campbell-l/g__robinson
# ../maildir/campbell-l/miscellaneous
# ../maildir/campbell-l/deleted_items
# ../maildir/campbell-l/john_shafer
# ../maildir/campbell-l/southwest_environmental_team
# ../maildir/campbell-l/sundevil_pipeline_project
# ../maildir/campbell-l/rocky_mountain_elk_foundation
# ../maildir/campbell-l/c_s_no__9_remediation
# ../maildir/campbell-l/prc
# ../maildir/campbell-l/_sent_mail
# ../maildir/campbell-l/nsps_for_turbines
# ../maildir/campbell-l/north_crawar_remediation

# %%
print("start")
import sqlite3
print("sqlite3 loaded")
import os
from email.parser import Parser
from datetime import datetime

# --- Configuration ---
# Path to the root of the Enron dataset (the 'maildir' folder)
DATASET_PATH = "../maildir" 
# Name for the output database
DB_PATH = "enron2.db"
# ---------------------

def create_database(db_path):
    """
    Creates the database and the four tables with the specified schema.
    """
    print(f"Creating database schema at {db_path}...")
    conn = sqlite3.connect(db_path)
    c = conn.cursor()

    # 1. Employeelist Table
    # This table will be created but left empty. Populating it is the 
    # core data cleaning task (e.g., deduplicating users).
    c.execute('''
    CREATE TABLE IF NOT EXISTS Employeelist (
        eid INTEGER PRIMARY KEY AUTOINCREMENT,
        user_name TEXT UNIQUE NOT NULL,        
        firstName TEXT,
        lastName TEXT,
        status TEXT
    )
    ''')
    
    # 2. Message Table
    c.execute('''
    CREATE TABLE IF NOT EXISTS Message (
        mid INTEGER PRIMARY KEY AUTOINCREMENT,
        sender TEXT,
        eid INTEGER,
        date TEXT,
        message_id TEXT,
        subject TEXT,
        body TEXT,
        folder TEXT,
        length_character INTEGER,
        length_word INTEGER,
        FOREIGN KEY (eid) REFERENCES Employeelist (eid)
    )
    ''')

    # 3. Recipientinfo Table
    c.execute('''
    CREATE TABLE IF NOT EXISTS Recipientinfo (
        rid INTEGER PRIMARY KEY AUTOINCREMENT,
        mid INTEGER,
        rtype TEXT,
        rvalue TEXT,
        FOREIGN KEY (mid) REFERENCES Message (mid)
    )
    ''')

    # 4. Referenceinfo Table
    c.execute('''
    CREATE TABLE IF NOT EXISTS Referenceinfo (
        rfid INTEGER PRIMARY KEY AUTOINCREMENT,
        mid INTEGER,
        reference TEXT,
        FOREIGN KEY (mid) REFERENCES Message (mid)
    )
    ''')

    conn.commit()
    conn.close()
    print("Database schema created successfully.")

def parse_date(input_string: str) -> str:

    parse_format = "%a, %d %b %Y %H:%M:%S %z"
    output_format = "%d/%m/%Y"

    # Remove the timezone name part ' (PDT)' for robust parsing.
    # We parse up to the numeric offset '-0700'.
    date_part = input_string.rsplit(' ', 1)[0]

    dt = datetime.strptime(date_part, parse_format)

    formatted_date = dt.strftime(output_format)
    
    return formatted_date

def parse_recipients(header_string):
    """
    Parses a 'To', 'Cc', or 'Bcc' header string into a list of emails.
    Handles comma-separated lists.
    """
    if not header_string:
        return []
    
    # Simple split on comma. More complex regex could be used
    # for names vs. emails, but this is robust for addresses.
    recipients = [r.strip() for r in header_string.split(',') if r.strip()]
    return recipients

def parse_maildir(dataset_path, db_path):
    """
    Walks the maildir directory, parses each email, and inserts data
    into the Message, Recipientinfo, and Referenceinfo tables.
    """
    conn = sqlite3.connect(db_path)
    c = conn.cursor()
    
    # Use the built-in email Parser
    parser = Parser()
    
    print(f"Starting to parse email files from {dataset_path}...")
    file_count = 0
    
    for root, dirs, files in os.walk(dataset_path):

        rootlist = os.path.normpath(root).split(os.sep)
        depth = len(rootlist)
        
        if depth == 4:
            user_name = rootlist[2]
            c.execute('''
            INSERT OR IGNORE INTO Employeelist (user_name, firstName, lastName, status)
            VALUES (?, Null, ?, Null)
            ''', (user_name, user_name.split('-')[0]))
            current_eid = c.lastrowid
            
            folder_name = rootlist[3]

        for file_name in files:
            # Per your description, files end with a period
            if not file_name.endswith('.'):
                continue

            file_path = os.path.join(root, file_name)
            
            try:
                with open(file_path, 'r', encoding='latin-1') as f:
                    raw_email = f.read()
                
                # Parse the raw email text
                msg = parser.parsestr(raw_email)
                
                # 1. Insert into Message table
                sender = msg.get('From')
                date = parse_date(msg.get('Date'))
                message_id = msg.get('Message-ID')
                subject = msg.get('Subject')
                # The 'X-Folder' header contains the logical Outlook folder
                # folder = msg.get('X-Folder')
                
                # Get the email body (payload)
                body = ""
                if msg.is_multipart():
                    for part in msg.walk():
                        ctype = part.get_content_type()
                        if ctype == 'text/plain':
                            body = part.get_payload(decode=True)
                            try:
                                # Try decoding as utf-8, fall back to latin-1
                                body = body.decode('utf-8')
                            except UnicodeDecodeError:
                                body = body.decode('latin-1')
                            break
                else:
                    body = msg.get_payload(decode=True)
                    try:
                        body = body.decode('utf-8')
                    except UnicodeDecodeError:
                        body = body.decode('latin-1')
                        
                body = body.strip()
                length_character = len(body)
                length_word = len(body.split())

                c.execute('''
                INSERT INTO Message (sender, eid, date, message_id, subject, body, folder, length_character, length_word)
                VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                ''', (sender, current_eid, date, message_id, subject, body, folder_name, length_character, length_word))
                
                # Get the mid (primary key) of the message we just inserted
                current_mid = c.lastrowid
                
                # 2. Insert into Recipientinfo table
                to_list = parse_recipients(msg.get('To'))
                cc_list = parse_recipients(msg.get('Cc'))
                bcc_list = parse_recipients(msg.get('Bcc'))
                
                for recipient in to_list:
                    c.execute('''
                    INSERT INTO Recipientinfo (mid, rtype, rvalue)
                    VALUES (?, 'to', ?)
                    ''', (current_mid, recipient))
                
                for recipient in cc_list:
                    c.execute('''
                    INSERT INTO Recipientinfo (mid, rtype, rvalue)
                    VALUES (?, 'cc', ?)
                    ''', (current_mid, recipient))

                for recipient in bcc_list:
                    c.execute('''
                    INSERT INTO Recipientinfo (mid, rtype, rvalue)
                    VALUES (?, 'bcc', ?)
                    ''', (current_mid, recipient))

                # 3. Insert into Referenceinfo table
                # Store the entire raw email for reference
                c.execute('''
                INSERT INTO Referenceinfo (mid, reference)
                VALUES (?, ?)
                ''', (current_mid, raw_email))
                
                file_count += 1
                if file_count % 5000 == 0:
                    print(f"Processed {file_count} emails. Committing to database...")
                    conn.commit()

            except Exception as e:
                print(f"Error processing file {file_path}: {e}")
                
    # Final commit and close
    conn.commit()
    conn.close()
    print(f"\n--- Processing Complete ---")
    print(f"Total emails parsed and inserted: {file_count}")
    print(f"Database saved to {db_path}")

if not os.path.isdir(DATASET_PATH):
    print(f"Error: Dataset path '{DATASET_PATH}' not found.")
    print("Please download the Enron dataset and place it in that folder,")
    print("or update the DATASET_PATH variable in the script.")
else:
    create_database(DB_PATH)
    parse_maildir(DATASET_PATH, DB_PATH)
# Out:
# start
# sqlite3 loaded
# Creating database schema at enron2.db...
# Database schema created successfully.
# Starting to parse email files from ../maildir...
# Processed 5000 emails. Committing to database...
# Processed 10000 emails. Committing to database...
# Processed 15000 emails. Committing to database...
# Processed 20000 emails. Committing to database...
# Processed 25000 emails. Committing to database...
# Processed 30000 emails. Committing to database...
# Processed 35000 emails. Committing to database...
# Processed 40000 emails. Committing to database...
# Processed 45000 emails. Committing to database...
# Processed 50000 emails. Committing to database...
# Processed 55000 emails. Committing to database...
# Processed 60000 emails. Committing to database...
# Processed 65000 emails. Committing to database...
# Processed 70000 emails. Committing to database...
# Processed 75000 emails. Committing to database...
# Processed 80000 emails. Committing to database...
# Processed 85000 emails. Committing to database...
# Processed 90000 emails. Committing to database...
# Processed 95000 emails. Committing to database...
# Processed 100000 emails. Committing to database...
# Processed 105000 emails. Committing to database...
# Processed 110000 emails. Committing to database...
# Processed 115000 emails. Committing to database...
# Processed 120000 emails. Committing to database...
# Processed 125000 emails. Committing to database...
# Processed 130000 emails. Committing to database...
# Processed 135000 emails. Committing to database...
# Processed 140000 emails. Committing to database...
# Processed 145000 emails. Committing to database...
# Processed 150000 emails. Committing to database...
# Processed 155000 emails. Committing to database...
# Processed 160000 emails. Committing to database...
# Processed 165000 emails. Committing to database...
# Processed 170000 emails. Committing to database...
# Processed 175000 emails. Committing to database...
# Processed 180000 emails. Committing to database...
# Processed 185000 emails. Committing to database...
# Processed 190000 emails. Committing to database...
# Processed 195000 emails. Committing to database...
# Processed 200000 emails. Committing to database...
# Processed 205000 emails. Committing to database...
# Processed 210000 emails. Committing to database...
# Processed 215000 emails. Committing to database...
# Processed 220000 emails. Committing to database...
# Processed 225000 emails. Committing to database...
# Processed 230000 emails. Committing to database...
# Processed 235000 emails. Committing to database...
# Processed 240000 emails. Committing to database...
# Processed 245000 emails. Committing to database...
# Processed 250000 emails. Committing to database...
# Processed 255000 emails. Committing to database...
# Processed 260000 emails. Committing to database...
# Processed 265000 emails. Committing to database...
# Processed 270000 emails. Committing to database...
# Processed 275000 emails. Committing to database...
# Processed 280000 emails. Committing to database...
# Processed 285000 emails. Committing to database...
# Processed 290000 emails. Committing to database...
# Processed 295000 emails. Committing to database...
# Processed 300000 emails. Committing to database...
# Processed 305000 emails. Committing to database...
# Processed 310000 emails. Committing to database...
# Processed 315000 emails. Committing to database...
# Processed 320000 emails. Committing to database...
# Processed 325000 emails. Committing to database...
# Processed 330000 emails. Committing to database...
# Processed 335000 emails. Committing to database...
# Processed 340000 emails. Committing to database...
# Processed 345000 emails. Committing to database...
# Processed 350000 emails. Committing to database...
# Processed 355000 emails. Committing to database...
# Processed 360000 emails. Committing to database...
# Processed 365000 emails. Committing to database...
# Processed 370000 emails. Committing to database...
# Processed 375000 emails. Committing to database...
# Processed 380000 emails. Committing to database...
# Processed 385000 emails. Committing to database...
# Processed 390000 emails. Committing to database...
# Processed 395000 emails. Committing to database...
# Processed 400000 emails. Committing to database...
# Processed 405000 emails. Committing to database...
# Processed 410000 emails. Committing to database...
# Processed 415000 emails. Committing to database...
# Processed 420000 emails. Committing to database...
# Processed 425000 emails. Committing to database...
# Processed 430000 emails. Committing to database...
# Processed 435000 emails. Committing to database...
# Processed 440000 emails. Committing to database...
# Processed 445000 emails. Committing to database...
# Processed 450000 emails. Committing to database...
# Processed 455000 emails. Committing to database...
# Processed 460000 emails. Committing to database...
# Processed 465000 emails. Committing to database...
# Processed 470000 emails. Committing to database...
# Processed 475000 emails. Committing to database...
# Processed 480000 emails. Committing to database...
# Processed 485000 emails. Committing to database...
# Processed 490000 emails. Committing to database...
# Processed 495000 emails. Committing to database...
# Processed 500000 emails. Committing to database...
# Processed 505000 emails. Committing to database...
# Processed 510000 emails. Committing to database...
# Processed 515000 emails. Committing to database...
#
# --- Processing Complete ---
# Total emails parsed and inserted: 517401
# Database saved to enron2.db

# %% [markdown]
# # cleanup data

# %%
import sqlite3
import pandas as pd

DB_PATH = "enron.db"


conn = sqlite3.connect(DB_PATH)
c = conn.cursor()

sql_query = "SELECT * FROM Message" 

df = pd.read_sql_query(sql_query, conn)

conn.commit()
conn.close()

# %%
import pandas as pd
import re


def remove_legal_disclaimer(text: str) -> str:
    """
    Removes the specific legal disclaimer from a text string.
    Uses regex to handle varying whitespace (newlines, spaces) between words.
    """
    
    # The specific text to remove
    disclaimer_text = """This e-mail message may contain legally privileged and/or confidential
    information. If you are not the intended recipient(s), or the employee
    or agent responsible for delivery of this message to the intended
    recipient(s), you are hereby notified that any dissemination,
    distribution or copying of this e-mail message is strictly prohibited.
    If you have received this message in error, please immediately notify
    the sender and delete this e-mail message from your computer."""

    # 1. Split disclaimer into individual words
    # 2. Escape regex special chars (like parens in 'recipient(s)')
    # 3. Join with \s+ to match any sequence of whitespace (space, tab, newline)
    pattern_parts = [re.escape(word) for word in disclaimer_text.split()]
    regex_pattern = r'\s*'.join(pattern_parts)

    # Compile pattern with IGNORECASE to catch capitalization variations
    # The pattern matches the sequence of words regardless of how they are wrapped
    compiled_pattern = re.compile(regex_pattern, re.IGNORECASE)

    # Replace found instances with an empty string
    cleaned_text = compiled_pattern.sub('', text)
    
    return cleaned_text.strip()

def clean_email_body(text):
    """
    Cleans email body by removing replies, headers, and specific legal disclaimers.
    """
    if pd.isna(text) or not isinstance(text, str):
        return ""

    text = remove_legal_disclaimer(text)
    # 1. Remove the Enron Disclaimer Block
    # Matches a block starting and ending with 10+ asterisks
    text = re.sub(r'\*{10,}[\s\S]*?\*{10,}', '', text)

    # 2. Remove "Original Message" separator lines
    # Replaces the separator with an empty string instead of splitting the text
    text = re.sub(r'-+\s*Original\s*Message\s*-+', '', text, flags=re.IGNORECASE)

    # 3. Remove Quoted text markers (>)
    # Only remove the '>' characters and leading whitespace, preserving the text content
    text = re.sub(r'^[\s>]+', '', text, flags=re.MULTILINE)

    # 4. Remove Header lines (From, Sent, To, Subject)
    # Replaces individual header lines with empty strings. 
    # We do this after removing '>' so we catch headers that were inside quotes.
    # Uses MULTILINE to match the start of lines.
    header_pattern = r'^\s*(?:From|Sent|To|Cc|Subject):\s+.*$'
    text = re.sub(header_pattern, '', text, flags=re.MULTILINE | re.IGNORECASE)

    # 5. Clean up extra whitespace created by removals
    # Collapse multiple newlines into two
    text = re.sub(r'\n{3,}', '\n\n', text)

    return text.strip()

# --- Example Usage ---

# The sample text provided
raw_email = """i am not kidding the kids were using the pot i had cleaned it and 
forgot to dry it. i have no idea are next trip. like i said we will pay 
if it does not dry

-----Original Message-----
From: 	"Danna Burkett" <dmburkett@houston.rr.com>@ENRON 
Sent:	Monday, November 12, 2001 4:01 PM
To:	Mckay, Brad
Subject:	Re: POC

Are you kidding me...what were you using a pot for...I thought you ate every
meal with Walter.......I hope you are kidding....give me the dates you are
going to be down there...I doubt we are going anytime soon but I would like
to know when you are going in case I have anything for you to take....I have
2 chairs that might need to go...I want Tiff to look at them first...
----- Original Message -----
From: <Brad.Mckay@enron.com>
To: <dmburkett@houston.rr.com>
Sent: Monday, November 12, 2001 3:33 PM
Subject: RE: POC


> the couch is just right, i did make the beds to the best of my ability. i
> did not use wally wally. i did however leave a pot that was wet on the
> bottom that created a stain i forgot that granite is a porous rock it
> absorbed the water quite well i hope that it will dry out if not we will
do
> what is necessary to fix it. i am totally serious about the granite
>
>     -----Original Message-----
>    From:   "Danna Burkett" <dmburkett@houston.rr.com>@ENRON
>    Sent:   Monday, November 12, 2001 3:19 PM
>    To:     Mckay, Brad
>    Subject:  Re: POC
>
>    Do you think the couch looks too big?....did you make the beds
>    good?....did
>    you use Wally Wally on the walls???....ha!!!
>    ----- Original Message -----
>    From: <Brad.Mckay@enron.com>
>    To: <dmburkett@houston.rr.com>
>    Sent: Monday, November 12, 2001 2:45 PM
>    Subject: RE: POC
>
>
>    > weekend was good,the place looks good,the boat was fun, we caught
>    trash
>    > fish on bait.
>    >
>    >     -----Original Message-----
>    >    From:   "Danna Burkett" <dmburkett@houston.rr.com>@ENRON
>    >    Sent:   Monday, November 12, 2001 2:41 PM
>    >    To:     Mckay, Brad
>    >    Subject:  POC
>    >
>    >
>    >    How was your weekend? Did you think the place  looked good? How
was
>    the
>    >    boat?......did you catch any fish? Back  atcha.....
>    >
>    >
>    >
>    >
**********************************************************************
>    > This e-mail is the property of Enron Corp. and/or its relevant
>    affiliate
>    and may contain confidential and privileged material for the sole use
of
>    the
>    intended recipient (s). Any review, use, distribution or disclosure by
>    others is strictly prohibited. If you are not the intended recipient
(or
>    authorized to receive for the recipient), please contact the sender or
>    reply
>    to Enron Corp. at enron.messaging.administration@enron.com and delete
>    all
>    copies of the message. This e-mail (and any attachments hereto) are not
>    intended to be an offer (or an acceptance) and do not create or
evidence
>    a
>    binding and enforceable contract between Enron Corp. (or any of its
>    affiliates) and the intended recipient or any other party, and may not
>    be
>    relied on by anyone as the basis of a contract by estoppel or
otherwise.
>    Thank you.
>    >
**********************************************************************
>
"""

# Apply cleaning
df['body_clean'] = df['body'].apply(clean_email_body)


# Display Results
print("--- ORIGINAL ---")
print(df['body'].iloc[0] + "...") # Printing just the start
print("\n--- CLEANED ---")
print(df['body_clean'].iloc[0])
i = 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 144
#     140     row['clean_length_word'] = clean_words
#     142     return row
# --> 144 df = df.apply(lambda x: count_clean_emails(x))
#     146 # Display Results
#     147 print("--- ORIGINAL ---")
#
# File ~/uva/bachelor_ki/bep/code/.venv/lib/python3.13/site-packages/pandas/core/frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File ~/uva/bachelor_ki/bep/code/.venv/lib/python3.13/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/uva/bachelor_ki/bep/code/.venv/lib/python3.13/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/uva/bachelor_ki/bep/code/.venv/lib/python3.13/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[40], line 144, in <lambda>(x)
#     140     row['clean_length_word'] = clean_words
#     142     return row
# --> 144 df = df.apply(lambda x: count_clean_emails(x))
#     146 # Display Results
#     147 print("--- ORIGINAL ---")
#
# Cell In[40], line 135, in count_clean_emails(row)
#     134 def count_clean_emails(row):
# --> 135     body_clean = row['body_clean']
#     136     clean_characters = len(body_clean)
#     137     clean_words = len(body_clean.split())
#
# File ~/uva/bachelor_ki/bep/code/.venv/lib/python3.13/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File ~/uva/bachelor_ki/bep/code/.venv/lib/python3.13/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File ~/uva/bachelor_ki/bep/code/.venv/lib/python3.13/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'body_clean'

# %%
i = 1

# %%
# Display Results
print("--- ORIGINAL ---")
print(df['body'].iloc[i]) # Printing just the start
print("\n--- CLEANED ---")
print(df['body_clean'].iloc[i])
print(i)

i += 1
# Out:
# --- ORIGINAL ---
# Toby,
# would you please make sure that some one on your team adds this enhancement item to the TMS worklist and that some one is assigned to writing up the requirements.
#
# thanks
#  -----Original Message-----
# From: 	Kuehl, Toby
# Sent:	Friday, September 14, 2001 12:43 PM
# To:	Hoang, Joe; Kedwaii, Hasan
# Cc:	Blair, Lynn; Holmes, Bradley; Dietz, Rick; Medeles, Gerry; Lee, Dennis
# Subject:	RE: Email Notifications
#
# Joe, Hasan,
#
# Just a thought on this issue.......
#
# In light of the concern from the customers that they are not receiving all of their cut notices, (which was a major topic up during the NNG winter ops meeting) we need to take a closer look at "why" the customers are not receiving them.  Is it the cache, wrong address, e-mail issues etc....  Is there something we do systematically to assure ourselves that these cut notifications are hitting their destinations?  I realize that once the e-mail is sent we have no control of it and there are times when customers are having mail server problems, but I just want to make sure it is at least getting out of our shop.  Can we make some kind of report that will generate on demand on what cut notifications were sent during the day?  This way we could see if they were sent, and if the customer did not receive them, we could look at a log file to verify if the cut notifications were generated and sent out via e-mail.  We, meaning Dennis or I do not have the capability to know exactly what was sent unless we contact you.  Again, this seems to be a major concern to the customers.  Let us know if you have any other ideas on this matter.
#
# Thx,
#
# Toby
#
#
#  -----Original Message-----
# From: 	Hoang, Joe
# Sent:	Friday, September 14, 2001 11:19 AM
# To:	Lee, Dennis; Kuehl, Toby; Kedwaii, Hasan
# Cc:	Blair, Lynn; Holmes, Bradley; Dietz, Rick; Medeles, Gerry
# Subject:	RE: Email Notifications
#
# Dennis,
# Unfortunately, the database audit trail does not handle deletion very well.
# It will log when the record was added and modified.  For deletes,
# it only logs that the record was deleted, not when.
# I cannot tell whether the entry for Jimmy Knight was deleted prior to the
# running of the process or not.
# The only thing I can confirm is that we did send out the email to him
# last night after the evening cycle.  This contract was not cut during
# the non-grid cycle this morning so no email went out.
#
# However, currently only jmosher and tjones show up  with the shipper cut notices
# for this contract if it got cut during the Intraday 1 cycle.
#
# To eliminate any doubts, I will change the process to totally recache contract/contacts information
# before processing email.
#
# Thanks,
# Joe
#
#
#
#  -----Original Message-----
# From: 	Lee, Dennis
# Sent:	Friday, September 14, 2001 10:07 AM
# To:	Hoang, Joe; Kuehl, Toby; Kedwaii, Hasan
# Cc:	Blair, Lynn; Holmes, Bradley; Dietz, Rick
# Subject:	RE: Email Notifications
#
# What about the changes for Jerry Knight?
#
# DL
#
#  -----Original Message-----
# From: 	Hoang, Joe
# Sent:	Friday, September 14, 2001 10:05 AM
# To:	Lee, Dennis; Kuehl, Toby; Kedwaii, Hasan
# Cc:	Blair, Lynn; Holmes, Bradley; Dietz, Rick
# Subject:	RE: Email Notifications
#
# Dennis,
# According to the database audit trail, the contact record for Jimmy Mosher was created
# on 9/13 , 9:11 am.  However , that record did not have an email address on it.
# This morning, (9/14 9:02 am), this record was modified to include the email address of
# jmosher@oneok.com.
#
# For Theresa, the original contact record was created on 9/13 9:14 am without an email address.
# This record was updated with tjones@oneok.com at 9/14 9:02 am.
#
# The latest modification was made after we send out the notices this morning,  which happened
# at 8:55am.  The next time that we process the emails, at the end of IDay1  cycle, around 1:30 pm,
# these folks would receive their email notifications if this contract is cut again.
#
# Thanks,
# Joe
#
#  -----Original Message-----
# From: 	Lee, Dennis
# Sent:	Friday, September 14, 2001 9:21 AM
# To:	Kuehl, Toby; Hoang, Joe; Kedwaii, Hasan
# Cc:	Blair, Lynn; Holmes, Bradley; Dietz, Rick; Lee, Dennis
# Subject:	Email Notifications
#
# I made several changes to Email notifications yesterday at our shipper's request.  This morning, I received a call from the same shipper stating that the wrong person is still receiving the changes.  I checked the system and the changes ARE in PLE.
#
# Specifically, I made a change to LE # 13229 Oneok Midstream (NNG Contract Number 105279) listing Theresa Jones and Jimmie Mosher to receive Bumping Notices and Shipper Cut Notices for NNG.  Jerry Knight received the notification this morning, Theresa and Jimmie did not.
#
# The changes were made yesterday afternoon in PLE and CMS.
#
# Does the cache need to be refreshed?  Is there a system problem?  Is there anything we can do to prevent this in the future?
#
# It seems there are several occasions when I make changes in PLE that for whatever reason do not make it to the downstream systems for customer notification.
#
# Your prompt attention to this matter will be greatly appreciated.
#
# Dennis P. Lee
# ETS
# Gas Logistics
# (713) 853-1715
# dennis.lee@enron.com
#
# --- CLEANED ---
# Toby,
# would you please make sure that some one on your team adds this enhancement item to the TMS worklist and that some one is assigned to writing up the requirements.
# thanks
#
# Joe, Hasan,
# Just a thought on this issue.......
# In light of the concern from the customers that they are not receiving all of their cut notices, (which was a major topic up during the NNG winter ops meeting) we need to take a closer look at "why" the customers are not receiving them.  Is it the cache, wrong address, e-mail issues etc....  Is there something we do systematically to assure ourselves that these cut notifications are hitting their destinations?  I realize that once the e-mail is sent we have no control of it and there are times when customers are having mail server problems, but I just want to make sure it is at least getting out of our shop.  Can we make some kind of report that will generate on demand on what cut notifications were sent during the day?  This way we could see if they were sent, and if the customer did not receive them, we could look at a log file to verify if the cut notifications were generated and sent out via e-mail.  We, meaning Dennis or I do not have the capability to know exactly what was sent unless we contact you.  Again, this seems to be a major concern to the customers.  Let us know if you have any other ideas on this matter.
# Thx,
# Toby
#
# Dennis,
# Unfortunately, the database audit trail does not handle deletion very well.
# It will log when the record was added and modified.  For deletes,
# it only logs that the record was deleted, not when.
# I cannot tell whether the entry for Jimmy Knight was deleted prior to the
# running of the process or not.
# The only thing I can confirm is that we did send out the email to him
# last night after the evening cycle.  This contract was not cut during
# the non-grid cycle this morning so no email went out.
# However, currently only jmosher and tjones show up  with the shipper cut notices
# for this contract if it got cut during the Intraday 1 cycle.
# To eliminate any doubts, I will change the process to totally recache contract/contacts information
# before processing email.
# Thanks,
# Joe
#
# What about the changes for Jerry Knight?
# DL
#
# Dennis,
# According to the database audit trail, the contact record for Jimmy Mosher was created
# on 9/13 , 9:11 am.  However , that record did not have an email address on it.
# This morning, (9/14 9:02 am), this record was modified to include the email address of
# jmosher@oneok.com.
# For Theresa, the original contact record was created on 9/13 9:14 am without an email address.
# This record was updated with tjones@oneok.com at 9/14 9:02 am.
# The latest modification was made after we send out the notices this morning,  which happened
# at 8:55am.  The next time that we process the emails, at the end of IDay1  cycle, around 1:30 pm,
# these folks would receive their email notifications if this contract is cut again.
# Thanks,
# Joe
#
# I made several changes to Email notifications yesterday at our shipper's request.  This morning, I received a call from the same shipper stating that the wrong person is still receiving the changes.  I checked the system and the changes ARE in PLE.
# Specifically, I made a change to LE # 13229 Oneok Midstream (NNG Contract Number 105279) listing Theresa Jones and Jimmie Mosher to receive Bumping Notices and Shipper Cut Notices for NNG.  Jerry Knight received the notification this morning, Theresa and Jimmie did not.
# The changes were made yesterday afternoon in PLE and CMS.
# Does the cache need to be refreshed?  Is there a system problem?  Is there anything we can do to prevent this in the future?
# It seems there are several occasions when I make changes in PLE that for whatever reason do not make it to the downstream systems for customer notification.
# Your prompt attention to this matter will be greatly appreciated.
# Dennis P. Lee
# ETS
# Gas Logistics
# (713) 853-1715
# dennis.lee@enron.com
# 13

# %%
# 100x faster
df['clean_length_character'] = df['body_clean'].str.len()
df['clean_length_word'] = df['body_clean'].str.split().str.len()

# %%
conn = sqlite3.connect(DB_PATH)

# Write to new table 'similarities'
# if_exists='replace' drops the table if it exists and creates a new one
# if_exists='append' adds to it
df.to_sql(
    name='Message',
    con=conn,
    if_exists='replace', 
    index=False,
    chunksize=10000  # Write in batches to save memory
)

cursor = conn.cursor()
cursor.execute("CREATE INDEX IF NOT EXISTS idx_sim_mid ON Message (mid)")
conn.commit()

conn.close()

# %%
#TODO: make a python file to run it on the other computer and then have it write it over ssh back.

# %%
# auto backup the enron.db to google drive.

# %%
# make the script git add . and commit automatically when ran if there are changes and prompt to give a reason.
# and make the server git pull as well.

# %%
N = 170_589
mu = 309.74

# %%
D = mu * N * 4 * 7

# %%
P = 2.2 * 10 ** 8

# %%
train_flops = D * P * 6

# %%
id_lenght = 10
beam_width = 10
search_flops = 2 * P * N * id_lenght * beam_width

# %%
troughput = 124 * 10 ** 12  # 124 TFLOPS

# %%
train_time = train_flops / troughput
train_beam_time = (train_flops + search_flops) / troughput
print("in seconds:")
print(train_time)
print(train_beam_time)
print("in minutes:")
print(train_time / 60)
print(train_beam_time / 60)
print("in hours:")
print(train_time / (60 * 60))
print(train_beam_time / (60 * 60))
# Out:
# in seconds:
# 15749.203502787097
# 15809.735083432259
# in minutes:
# 262.4867250464516
# 263.495584723871
# in hours:
# 4.374778750774194
# 4.391593078731183

# %%
print(27.72 * 10 ** 16 / (124 * 10 ** 12) / (60* 60) * 3 * 5)
# Out:
# 9.314516129032258

# %%
pass
